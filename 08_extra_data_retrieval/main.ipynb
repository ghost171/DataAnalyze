# %% [markdown]
# # Регулярные выражения

# %% [markdown]
# **Регулярные выражения** _\(regular expressions, RegExp\)_ — это формальный язык для операций \(поиск, замена и т.п.\) с подстроками в тексте. Иными словами, это способ задать некоторый паттерн и найти / заменить на что-либо те кусочки текста, которые с ним совпадают.

# %% [markdown]
# <img width='450px' src="images/use-regex.jpg"></img>

# %% [markdown]
# Некоторые люди, когда сталкиваются с проблемой, думают:
#
#     «Я знаю, я решу её с помощью регулярных выражений.»
#
# Теперь у них **ДВЕ** проблемы.

# %% [markdown]
# ## Что почитать и посмотреть?
#
# 1. Хороший [«быстрый старт»](https://tproger.ru/translations/regular-expression-python/) с задачками от TProger.
# 2. Отличный [туториал](https://habr.com/post/349860/) с задачками на Хабре.
# 3. Регулярные выражения за 20 минут [видео на YouTube](https://www.youtube.com/watch?v=_pLpx6btq6U).
# 4. [Документация](https://docs.python.org/3/library/re.html) к стандартной библиотеке.

# %%
import re

# %% [markdown]
# Отладчики регулярных выражений:
# * https://www.debuggex.com/ ;
# * https://regex101.com/ .

# %% [markdown]
# `bash`-утилиты, использующие регулярные выражения: [`sed`](https://losst.ru/komanda-sed-linux), [`grep`](https://losst.ru/gerp-poisk-vnutri-fajlov-v-linux).
#
# `IDE -> Find & Replace -> RegExp`

# %% [markdown]
# ### re.search
#
# Эта функция, ищет заданный шаблон в **любом** месте строки, но возвращает только первое найденное совпадение.
#
# Аргументы: что найти, где найти.

# %%
re.search(r'cat', 'the fat cat is on the mat')
# Out:
# <re.Match object; span=(8, 11), match='cat'>

# %%
re.search(r'cat', 'the fat cat is on the mat').group(0)
# Out:
# 'cat'

# %% [markdown]
# ### re.findall
#
# Эта функция возвращает список **всех** найденных совпадений в любом месте строки. Аргументы у нее те же, что и у предыдущей функции.
#
# **Замечание:** если вы уверены, что в строке только одно вхождение, предпочитайте `re.search`.

# %%
re.findall(r'the', 'the fat cat is on the mat')
# Out:
# ['the', 'the']

# %% [markdown]
# ### re.sub
#
# Эта функция ищет шаблон в строке и заменяет его на указанную подстроку. Если шаблон не найден, строка остается неизменной.
#
# Аргументы: что заменить; на что заменить; где заменить.
#
# Заменяются все подстроки, которые нашлись по шаблону.

# %%
re.sub(r'the', 'my', 'the fat cat is on the mat')
# Out:
# 'my fat cat is on my mat'

# %% [markdown]
# ### Как задать регулярное выражение?

# %% [markdown]
# * `\d` – любая цифра (`[0-9]`);
# * `\w` – любая цифра, любая латинская буква или символ `_` (`[0-9a-zA-Z_]`);
# * `\s` – любой пробельный символ;
# * `[...]` – любой из перечисленных символов, например, `[12345]` (или диапазоны, см. выше);
# * `[^...]` – любой символ кроме перечисленных;
# * `^` – символ начала строки;
# * `$` – символ конца строки;
# * `\b` – граница слова.

# %%
# найти все слова из 3-х букв, кончающиеся на at

re.findall(r'\b\wat\b', 'the fat cat is on the mat')
# Out:
# ['fat', 'cat', 'mat']

# %%
# найти слово из 3-х букв, кончающееся на at и стоящее в конце строки

re.findall(r'\b\wat$', 'the fat cat is on the mat')
# Out:
# ['mat']

# %% [markdown]
# Группировка выражений выполняется с поомощью операторов `(...)` и `|`.

# %%
# найти все слова из 3-х букв, начинающиеся или заканчивающиеся с символа t

re.findall(r'\b(t\w\w|\w\wt)\b', 'the fat cat is on the mat')
# Out:
# ['the', 'fat', 'cat', 'the', 'mat']

# %% [markdown]
# Кроме того, можно задавать длину строки, которую мы ищем:
#
# * `?` — предыдущий символ/группа может быть, а может не быть;
# * `+` — предыдущий символ/группа может повторяться 1 и более раз;
# * `*` — предыдущий символ/группа может повторяться 0 и более раз;
# * `{n,m}` — предыдущий символ/группа может повторяться от от n до m включительно;
# * `{n,}` — предыдущий символ/группа в скобках может повторяться n и более раз;
# * `{,m}` — предыдущий символ/группа может повторяться до m раз;
# * `{n}` — предыдущий символ/группа повторяется n раз.

# %%
# найти все слова из 2-х букв, начинающиеся или заканчивающиеся с символа t

re.findall(r'\b\w{2}\b', 'the fat cat is on the mat')
# Out:
# ['is', 'on']

# %%
# найти все слова из 3-х букв, начинающиеся или заканчивающиеся с символа t

re.findall(r'\b(t\w{2}|\w{2}t)\b', 'the fat cat is on the mat')
# Out:
# ['the', 'fat', 'cat', 'the', 'mat']

# %% [markdown]
# ### Еще несколько примеров

# %% [markdown]
# Найти число с плавающей точкой

# %%
re.search('\d+(\.\d+)?', '123')
# Out:
# <re.Match object; span=(0, 3), match='123'>

# %%
re.search('\d+(\.\d+)?', '12.3')
# Out:
# <re.Match object; span=(0, 4), match='12.3'>

# %%
re.search('\d+(\.\d+)?', '12.')
# Out:
# <re.Match object; span=(0, 2), match='12'>

# %% [markdown]
# Определение языка: украинский или русский

# %%
records = [
    'Знову до справи: як отримати роботу після тривалої перерви',
    'Гендерные «качели»: карьерные провалы и зарплатная недостаточность',
    'Агроперспективні пропозиції на ринку праці: 15 актуальних вакансій',
    'Переговори: як досягти бажаного результату?',
    'Не досягненнями єдиними: як хобі допоможе отримати роботу',
    'Работа в рекламе: три неочевидные профессии',
]

# %%
def is_ukraine(s):
    is_ok = re.search(r'\b[а-я]*[іїє][а-я]*\b', s, flags=re.IGNORECASE) is not None
    is_ok = is_ok or re.search(r'\b(як|де)\b', s, flags=re.IGNORECASE) is not None
    return is_ok

# %%
for s in records:
    print(is_ukraine(s), s, sep='\t')
# Out:
# True	Знову до справи: як отримати роботу після тривалої перерви
# False	Гендерные «качели»: карьерные провалы и зарплатная недостаточность
# True	Агроперспективні пропозиції на ринку праці: 15 актуальних вакансій
# True	Переговори: як досягти бажаного результату?
# True	Не досягненнями єдиними: як хобі допоможе отримати роботу
# False	Работа в рекламе: три неочевидные профессии

# %% [markdown]
# Удаление лишней обвязки

# %%
s = '''
<script>
    window._io_config = window._io_config || {};
    window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
    window._io_config["0.2.0"].push({
      page_url: window.location.href,
      page_url_canonical: "https://perito-burrito.com/posts/russia-2020",
      page_title: "Как 2020 год навсегда изменит путешествия по России",
      page_type: "article",
      page_language: "en",
      article_authors: ["Саша Воробьев"],
      article_categories: ["Россия","Советы"],
      article_word_count: "1731",
      article_publication_date: "Mon, 27 Jul 2020 10:04:08 +0000"
    });
</script>
'''

print(s)
# Out:
# <script>
#     window._io_config = window._io_config || {};
#     window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
#     window._io_config["0.2.0"].push({
#       page_url: window.location.href,
#       page_url_canonical: "https://perito-burrito.com/posts/russia-2020",
#       page_title: "Как 2020 год навсегда изменит путешествия по России",
#       page_type: "article",
#       page_language: "en",
#       article_authors: ["Саша Воробьев"],
#       article_categories: ["Россия","Советы"],
#       article_word_count: "1731",
#       article_publication_date: "Mon, 27 Jul 2020 10:04:08 +0000"
#     });
# </script>

# %%
r = re.search(r'push\((.*?)\);', s, flags=re.DOTALL).group(1)
r = r.strip('\n{}')

print(r)
# Out:
#       page_url: window.location.href,
#       page_url_canonical: "https://perito-burrito.com/posts/russia-2020",
#       page_title: "Как 2020 год навсегда изменит путешествия по России",
#       page_type: "article",
#       page_language: "en",
#       article_authors: ["Саша Воробьев"],
#       article_categories: ["Россия","Советы"],
#       article_word_count: "1731",
#       article_publication_date: "Mon, 27 Jul 2020 10:04:08 +0000"

# %% [markdown]
# # Структура URL

# %% [markdown]
# http://www.example.com:80/path/to/myfile.html?key1=value1&key2=value2#SomewhereInTheDocument
#
# <img width='480px' src="https://mdn.mozillademos.org/files/8013/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8015/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8017/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8019/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8021/mdn-url-protocol@x2.png"></img>
# <img width='480px' src="https://mdn.mozillademos.org/files/8023/mdn-url-protocol@x2.png"></img>
#
# https://developer.mozilla.org/ru/docs/Learn/Understanding_URLs

# %%
from urllib.parse import urlparse, parse_qsl, parse_qs

url = "http://www.example.com:80/path/to/myfile.html?key1=value1&key2=value2#SomewhereInTheDocument"
url_parsed = urlparse(url)
url_parsed
# Out:
# ParseResult(scheme='http', netloc='www.example.com:80', path='/path/to/myfile.html', params='', query='key1=value1&key2=value2', fragment='SomewhereInTheDocument')

# %%
url_parsed.path
# Out:
# '/path/to/myfile.html'

# %%
dict(parse_qsl(url_parsed.query))
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %% [markdown]
# # Типы HTTP запросов и ответов

# %% [markdown]
# <img width='500px' src="images/swagger-petstore-endpoint-methods.png"></img>

# %% [markdown]
# <img width='800px' src="images/responses.jpg"></img>

# %% [markdown]
# Табличка с типами ответов: [клац раз](https://www.steveschoger.com/status-code-poster/img/status-code.png) и [клац два](https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BA%D0%BE%D0%B4%D0%BE%D0%B2_%D1%81%D0%BE%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D1%8F_HTTP).

# %% [markdown]
# [Документация](http://docs.python-requests.org/) по библиотеке requests.

# %%
import requests

# %% [markdown]
# Пример: [transfer.sh](https://transfer.sh/)

# %%
r_put = requests.put('https://transfer.sh/arg.txt', data='Bonjour le monde!')
r_put
# Out:
# <Response [200]>

# %%
r_put.ok, r_put.status_code
# Out:
# (True, 200)

# %%
print(r_put.text)
# Out:
# https://transfer.sh/IjfrVt/arg.txt

# %%
r_get = requests.get(r_put.text)
r_get
# Out:
# <Response [200]>

# %%
r_get.text
# Out:
# 'Bonjour le monde!'

# %% [markdown]
# Пример: [controlc.com](https://controlc.com/) (аналог pastebin.com)

# %%
page = requests.post('https://controlc.com/index.php?act=submit', data={
    'subdomain': '',
    'antispam': 1,
    'website': '',
    'paste_title': 'Заметка',
    'input_text': 'Привет, Техносфера!',
    'timestamp': 'c756e2892de7c0a5e89b4e70cd65c1ef',
    'paste_password': '',
    'code': 0,
}, headers={'accept-encoding': 'identity', 'referer': 'https://controlc.com/'})

page
# Out:
# <Response [200]>

# %%
from lxml import html as lhtml

tree = lhtml.fromstring(page.text)
urls = tree.xpath('//a[text()="Paste submitted successfully! (view)"]/@href')
print(*urls)
# Out:
# https://controlc.com/64cc565d

# %% [markdown]
# # Работа с JSON

# %%
import json

# %% [markdown]
# prepare token: https://developer.spotify.com/console/get-track/?id=3n3Ppam7vgaVa1iaRUc9Lp

# %%
with open('spotify-api-token.key', mode='r') as f_key:
    spotify_api_token = f_key.readline().strip()
    

class SpotifyAPI:    
    def __init__(self, token):
        self._token = token

    def get_track_info(self, track_id, market='US'):
        # посылаем get запрос, указываем аргументы и заголовки
        ret = requests.get("https://api.spotify.com/v1/tracks/{}".format(track_id),
                           params={'market': market,},
                           headers={'Authorization': f'Bearer {self._token}'})
        return ret


spotify = SpotifyAPI(spotify_api_token)
r = spotify.get_track_info('7gVGBGI4ZqvkYBlh2LdrQy', market='US')
r.status_code
# Out:
# 200

# %%
print(r.text)
# Out:
# {
#   "album" : {
#     "album_type" : "album",
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/6FQqZYVfTNQ1pCqfkwVFEa"
#       },
#       "href" : "https://api.spotify.com/v1/artists/6FQqZYVfTNQ1pCqfkwVFEa",
#       "id" : "6FQqZYVfTNQ1pCqfkwVFEa",
#       "name" : "Foals",
#       "type" : "artist",
#       "uri" : "spotify:artist:6FQqZYVfTNQ1pCqfkwVFEa"
#     } ],
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/album/5oT2zoIrVGJcbVZoNGGZwc"
#     },
#     "href" : "https://api.spotify.com/v1/albums/5oT2zoIrVGJcbVZoNGGZwc",
#     "id" : "5oT2zoIrVGJcbVZoNGGZwc",
#     "images" : [ {
#       "height" : 640,
#       "url" : "https://i.scdn.co/image/ab67616d0000b27338fe495ad75bd55c146125b6",
#       "width" : 640
#     }, {
#       "height" : 300,
#       "url" : "https://i.scdn.co/image/ab67616d00001e0238fe495ad75bd55c146125b6",
#       "width" : 300
#     }, {
#       "height" : 64,
#       "url" : "https://i.scdn.co/image/ab67616d0000485138fe495ad75bd55c146125b6",
#       "width" : 64
#     } ],
#     "name" : "Everything Not Saved Will Be Lost Pt. 1",
#     "release_date" : "2019-03-08",
#     "release_date_precision" : "day",
#     "total_tracks" : 10,
#     "type" : "album",
#     "uri" : "spotify:album:5oT2zoIrVGJcbVZoNGGZwc"
#   },
#   "artists" : [ {
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/artist/6FQqZYVfTNQ1pCqfkwVFEa"
#     },
#     "href" : "https://api.spotify.com/v1/artists/6FQqZYVfTNQ1pCqfkwVFEa",
#     "id" : "6FQqZYVfTNQ1pCqfkwVFEa",
#     "name" : "Foals",
#     "type" : "artist",
#     "uri" : "spotify:artist:6FQqZYVfTNQ1pCqfkwVFEa"
#   } ],
#   "disc_number" : 1,
#   "duration_ms" : 357419,
#   "explicit" : false,
#   "external_ids" : {
#     "isrc" : "GBAHT1800684"
#   },
#   "external_urls" : {
#     "spotify" : "https://open.spotify.com/track/1JMGjWpfBj2uctjMmjx4mb"
#   },
#   "href" : "https://api.spotify.com/v1/tracks/1JMGjWpfBj2uctjMmjx4mb",
#   "id" : "1JMGjWpfBj2uctjMmjx4mb",
#   "is_local" : false,
#   "is_playable" : true,
#   "linked_from" : {
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/7gVGBGI4ZqvkYBlh2LdrQy"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/7gVGBGI4ZqvkYBlh2LdrQy",
#     "id" : "7gVGBGI4ZqvkYBlh2LdrQy",
#     "type" : "track",
#     "uri" : "spotify:track:7gVGBGI4ZqvkYBlh2LdrQy"
#   },
#   "name" : "Exits",
#   "popularity" : 53,
#   "preview_url" : "https://p.scdn.co/mp3-preview/ef19a10b520acdca7d689841ba30cbd65f29a340?cid=774b29d4f13844c495f206cafdad9c86",
#   "track_number" : 2,
#   "type" : "track",
#   "uri" : "spotify:track:1JMGjWpfBj2uctjMmjx4mb"
# }

# %%
answer = json.loads(r.text)
type(answer)
# Out:
# dict

# %%
answer = r.json()
type(answer)
# Out:
# dict

# %%
answer_cut = {
    'artist':   answer['artists'][0]['name'],
    'name':     answer['name'],
    'duration': answer['duration_ms'] / 1000.0,
    'href':     answer['href'],
    'id':       answer['id'],
    'preview':  answer['preview_url'],
}
answer_cut
# Out:
# {'artist': 'Foals',
#  'name': 'Exits',
#  'duration': 357.419,
#  'href': 'https://api.spotify.com/v1/tracks/1JMGjWpfBj2uctjMmjx4mb',
#  'id': '1JMGjWpfBj2uctjMmjx4mb',
#  'preview': 'https://p.scdn.co/mp3-preview/ef19a10b520acdca7d689841ba30cbd65f29a340?cid=774b29d4f13844c495f206cafdad9c86'}

# %%
filename = urlparse(answer_cut['preview']).path.rsplit('/', 1)[-1] + '.mp3'

# NOTE: используем атрибут content для бинарных данных

with open(filename, 'wb') as f:
    data = requests.get(answer_cut['preview']).content
    f.write(data)
    
print(filename)
# Out:
# ef19a10b520acdca7d689841ba30cbd65f29a340.mp3

# %%
import IPython.display as ipd

ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# компактно сериализуем json в строку

json.dumps(answer_cut)
# Out:
# '{"artist": "Foals", "name": "Exits", "duration": 357.419, "href": "https://api.spotify.com/v1/tracks/1JMGjWpfBj2uctjMmjx4mb", "id": "1JMGjWpfBj2uctjMmjx4mb", "preview": "https://p.scdn.co/mp3-preview/ef19a10b520acdca7d689841ba30cbd65f29a340?cid=774b29d4f13844c495f206cafdad9c86"}'

# %%
# pretty print для json

print(json.dumps(answer_cut, indent=4, sort_keys=True))
# Out:
# {
#     "artist": "Foals",
#     "duration": 357.419,
#     "href": "https://api.spotify.com/v1/tracks/1JMGjWpfBj2uctjMmjx4mb",
#     "id": "1JMGjWpfBj2uctjMmjx4mb",
#     "name": "Exits",
#     "preview": "https://p.scdn.co/mp3-preview/ef19a10b520acdca7d689841ba30cbd65f29a340?cid=774b29d4f13844c495f206cafdad9c86"
# }

# %%
with open('/tmp/answer_cut.json', mode='w') as f_json:
    json.dump(answer_cut, f_json)

# %%
with open('/tmp/answer_cut.json', mode='r') as f_json:
    answer_cut = json.load(f_json)

answer_cut
# Out:
# {'artist': 'Foals',
#  'name': 'Exits',
#  'duration': 357.419,
#  'href': 'https://api.spotify.com/v1/tracks/1JMGjWpfBj2uctjMmjx4mb',
#  'id': '1JMGjWpfBj2uctjMmjx4mb',
#  'preview': 'https://p.scdn.co/mp3-preview/ef19a10b520acdca7d689841ba30cbd65f29a340?cid=774b29d4f13844c495f206cafdad9c86'}

# %%
# !cat /tmp/answer_cut.json
# Out:
# {"artist": "Foals", "name": "Exits", "duration": 357.419, "href": "https://api.spotify.com/v1/tracks/1JMGjWpfBj2uctjMmjx4mb", "id": "1JMGjWpfBj2uctjMmjx4mb", "preview": "https://p.scdn.co/mp3-preview/ef19a10b520acdca7d689841ba30cbd65f29a340?cid=774b29d4f13844c495f206cafdad9c86"}

# %%
# !cat /tmp/answer_cut.json | python -m json.tool
# Out:
# {
#     "artist": "Foals",
#     "name": "Exits",
#     "duration": 357.419,
#     "href": "https://api.spotify.com/v1/tracks/1JMGjWpfBj2uctjMmjx4mb",
#     "id": "1JMGjWpfBj2uctjMmjx4mb",
#     "preview": "https://p.scdn.co/mp3-preview/ef19a10b520acdca7d689841ba30cbd65f29a340?cid=774b29d4f13844c495f206cafdad9c86"
# }

# %%
# !cat /tmp/answer_cut.json | jq .
# Out:
# {
#   "artist": "Foals",
#   "name": "Exits",
#   "duration": 357.419,
#   "href": "https://api.spotify.com/v1/tracks/1JMGjWpfBj2uctjMmjx4mb",
#   "id": "1JMGjWpfBj2uctjMmjx4mb",
#   "preview": "https://p.scdn.co/mp3-preview/ef19a10b520acdca7d689841ba30cbd65f29a340?cid=774b29d4f13844c495f206cafdad9c86"
# }

# %% [markdown]
# ## А можно ли как-то ускорить процесс обкачки?

# %% [markdown]
# <span style="color:blue;font-weight:bold">Вопрос:</span> какая разница между процессами и потоками (threads)?

# %% [markdown]
# Глобальная блокировка интерпретатора ( global interpreter lock , **GIL** ) Python. Если два или более потока попытаются манипулировать одним и тем же объектом в одно и то же время, то неизбежно возникнут проблемы. Глобальная блокировка интерпретатора исправляет это. В любой момент времени действия может выполнять только один поток. Python автоматически переключается между потоками, когда в этом возникает необходимость.
#
# GIL в Python реализован как обычный lock.

# %% [markdown]
# Скачивание данных через библиотеку requsets – I/O операция, поэтому большую часть времени процессор не выполняет никаких задач, потому что ждёт, пока данные придут по сети.

# %%
from tqdm.notebook import tqdm

# %%
# %%time

n_post_first, n_post_final = 349000, 349200
n_step = 5

pages = [requests.get('https://habr.com/post/{}/'.format(post_id))
         for post_id in tqdm(range(n_post_first, n_post_final, n_step))]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=40.0), HTML(value='')))
# CPU times: user 912 ms, sys: 133 ms, total: 1.04 s
# Wall time: 15.4 s

# %%
from multiprocessing.dummy import Pool as ThreadPool

# %%
# %%time

n_post_first, n_post_final = 349000, 349200

def get_habr_post(post_id):
    return requests.get('https://habrahabr.ru/post/{}/'.format(post_id))

with ThreadPool(10) as pool:
    pages = pool.map(get_habr_post, range(n_post_first, n_post_final, n_step))

pool.join()   # same as wait pid
# Out:
# CPU times: user 1.55 s, sys: 273 ms, total: 1.83 s
# Wall time: 2.06 s

# %%
from multiprocessing import Pool

# %%
# %%time

n_post_first, n_post_final = 349000, 349200

def get_habr_post(post_id):
    return requests.get('https://habrahabr.ru/post/{}/'.format(post_id))

with Pool(processes=10) as pool:
    pages = pool.map(get_habr_post, range(n_post_first, n_post_final, n_step))

pool.join()   # same as wait pid
# Out:
# CPU times: user 50.5 ms, sys: 69.9 ms, total: 120 ms
# Wall time: 1.89 s

# %% [markdown]
# # robots.txt и sitemap.xml
#
# 1. Валидаторы:
#     * https://webmaster.yandex.ru/tools/robotstxt/
#     * https://technicalseo.com/seo-tools/robots-txt/
# 2. Все о robots.txt:
#     * https://help.mail.ru/webmaster/indexing/robots.txt
#     * https://yandex.ru/support/webmaster/controlling-robot/
#
# **Пример 1:** https://tproger.ru/robots.txt
#
# **Пример 2:** https://vc.ru/robots.txt

# %% [markdown]
# # Парсинг HTML-страничек

# %% [markdown]
# <img width='800px' src="https://q-bit.biz/uploads/article/Tegs_1539003896.png"></img>

# %% [markdown]
# Example: https://www.kinopoisk.ru/film/689066/

# %% [markdown]
# ## lxml
#
# <img width = '250px' src="images/lxml.png">
#
# https://lxml.de/tutorial.html

# %%
from lxml import etree, html as lhtml

# %%
tree = lhtml.fromstring(open('data/689066_2.html', 'r').read())

# %% [markdown]
# Так как html и xml имеют древовидную структуру, до любого элемента всегда существет единственный путь, XPath.
#
# https://www.w3schools.com/xml/xpath_intro.asp
#
# ```bash
# pip install cssselect   # для подержки CSS селекторов
# ```

# %%
film_info = {
    'title': tree.xpath('//h1[@itemprop="name"]/span/text()')[0],
    'title-original': tree.xpath('//span[starts-with(@class, "styles_originalTitle__")]')[0].text,
    'rating': float(tree.cssselect('a.film-rating-value')[0].text),   # поддержка CSS-селекторов
#     'rating': float(tree.xpath('//a[contains(@class, "film-rating-value")]/text()')[0])
}

film_info
# Out:
# {'title': 'Стражи Галактики',
#  'title-original': 'Guardians of the Galaxy',
#  'rating': 7.763}

# %% [markdown]
# Найдем ссылку на просмотр фильма.

# %%
watch = tree.xpath('//a[contains(@class, "kinopoisk-watch-online-button")]/attribute::href')
watch
# Out:
# ['https://hd.kinopoisk.ru/film/4a297ba39cb704fa9a81855f76ab1d73?from=button_online&watch=']

# %%
film_info['watch'] = watch
film_info
# Out:
# {'title': 'Стражи Галактики',
#  'title-original': 'Guardians of the Galaxy',
#  'rating': 7.763,
#  'watch': ['https://hd.kinopoisk.ru/film/4a297ba39cb704fa9a81855f76ab1d73?from=button_online&watch=']}

# %% [markdown]
# Вытащим ссылки на постеры.

# %%
image = tree.xpath('//img[contains(@class, "film-poster")]//attribute::srcset')
image
# Out:
# ['//avatars.mds.yandex.net/get-kinopoisk-image/1773646/2e6ab20b-7cf1-49e7-b465-bd5a71c13fa3/300x450 1x, //avatars.mds.yandex.net/get-kinopoisk-image/1773646/2e6ab20b-7cf1-49e7-b465-bd5a71c13fa3/600x900 2x']

# %%
image = tree.xpath('//img[contains(@class, "film-poster")]//attribute::srcset')[0]
image = image.split(', ')
image = ['https:' + img.split(' ', 1)[0] for img in image]
image
# Out:
# ['https://avatars.mds.yandex.net/get-kinopoisk-image/1773646/2e6ab20b-7cf1-49e7-b465-bd5a71c13fa3/300x450',
#  'https://avatars.mds.yandex.net/get-kinopoisk-image/1773646/2e6ab20b-7cf1-49e7-b465-bd5a71c13fa3/600x900']

# %%
film_info['posters'] = image
film_info
# Out:
# {'title': 'Стражи Галактики',
#  'title-original': 'Guardians of the Galaxy',
#  'rating': 7.763,
#  'watch': ['https://hd.kinopoisk.ru/film/4a297ba39cb704fa9a81855f76ab1d73?from=button_online&watch='],
#  'posters': ['https://avatars.mds.yandex.net/get-kinopoisk-image/1773646/2e6ab20b-7cf1-49e7-b465-bd5a71c13fa3/300x450',
#   'https://avatars.mds.yandex.net/get-kinopoisk-image/1773646/2e6ab20b-7cf1-49e7-b465-bd5a71c13fa3/600x900']}

# %% [markdown]
# Распарсим описание фильма.

# %%
info_desc = tree.xpath('//div[starts-with(@class, "styles_synopsisSection")]//text()')
info_desc
# Out:
# ['Отважному путешественнику Питеру Квиллу попадает в руки таинственный артефакт, принадлежащий могущественному и безжалостному злодею Ронану, строящему коварные планы по захвату Вселенной. Питер оказывается в центре межгалактической охоты, где жертва — он сам.',
#  'Единственный способ спасти свою жизнь — объединиться с четверкой нелюдимых изгоев: воинственным енотом по кличке Ракета, человекоподобным деревом Грутом, смертельно опасной Гаморой и одержимым жаждой мести Драксом, также известным как Разрушитель. Когда Квилл понимает, какой силой обладает украденный артефакт и какую опасность он представляет для вселенной, одиночка пойдет на все, чтобы сплотить случайных союзников для решающей битвы за судьбу галактики.']

# %%
info_desc = tree.xpath('//div[starts-with(@class, "styles_synopsisSection")]//text()')

film_info['description'] = '\n'.join(info_desc)
film_info
# Out:
# {'title': 'Стражи Галактики',
#  'title-original': 'Guardians of the Galaxy',
#  'rating': 7.763,
#  'watch': ['https://hd.kinopoisk.ru/film/4a297ba39cb704fa9a81855f76ab1d73?from=button_online&watch='],
#  'posters': ['https://avatars.mds.yandex.net/get-kinopoisk-image/1773646/2e6ab20b-7cf1-49e7-b465-bd5a71c13fa3/300x450',
#   'https://avatars.mds.yandex.net/get-kinopoisk-image/1773646/2e6ab20b-7cf1-49e7-b465-bd5a71c13fa3/600x900'],
#  'description': 'Отважному путешественнику Питеру Квиллу попадает в руки таинственный артефакт, принадлежащий могущественному и безжалостному злодею Ронану, строящему коварные планы по захвату Вселенной. Питер оказывается в центре межгалактической охоты, где жертва — он сам.\nЕдинственный способ спасти свою жизнь — объединиться с четверкой нелюдимых изгоев: воинственным енотом по кличке Ракета, человекоподобным деревом Грутом, смертельно опасной Гаморой и одержимым жаждой мести Драксом, также известным как Разрушитель. Когда Квилл понимает, какой силой обладает украденный артефакт и какую опасность он представляет для вселенной, одиночка пойдет на все, чтобы сплотить случайных союзников для решающей битвы за судьбу галактики.'}

# %% [markdown]
# ## Beautiful Soup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# <img width = '330px' src="images/bsoup.jpg">

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(open('data/689066_2.html', 'r').read(), 'html.parser')

# %%
soup = BeautifulSoup(open('data/689066_2.html', 'r').read(), 'lxml')

# %%
from operator import attrgetter, itemgetter

# %% [markdown]
# ### Соберем основную информацию о фильме

# %%
film_info = {
    'title': soup.find('h1', itemprop='name').find('span').text,
    'title-original': soup.find('span', class_=lambda s: s and s.startswith('styles_originalTitle__')).text,
    'rating': float(soup.select_one('a.film-rating-value').text)   # поддержка CSS-селекторов
}

film_info
# Out:
# {'title': 'Стражи Галактики',
#  'title-original': 'Guardians of the Galaxy',
#  'rating': 7.763}

# %%
desc = soup.find('div', itemprop='description')
desc = soup.find('div', class_=lambda s: s and s.startswith("styles_synopsisSection")).find_all('p')
desc
# Out:
# [<p class="styles_paragraph__2Otvx" data-tid="7044a75b">Отважному путешественнику Питеру Квиллу попадает в руки таинственный артефакт, принадлежащий могущественному и безжалостному злодею Ронану, строящему коварные планы по захвату Вселенной. Питер оказывается в центре межгалактической охоты, где жертва — он сам.</p>,
#  <p class="styles_paragraph__2Otvx" data-tid="7044a75b">Единственный способ спасти свою жизнь — объединиться с четверкой нелюдимых изгоев: воинственным енотом по кличке Ракета, человекоподобным деревом Грутом, смертельно опасной Гаморой и одержимым жаждой мести Драксом, также известным как Разрушитель. Когда Квилл понимает, какой силой обладает украденный артефакт и какую опасность он представляет для вселенной, одиночка пойдет на все, чтобы сплотить случайных союзников для решающей битвы за судьбу галактики.</p>]

# %%
desc[0].text
# Out:
# 'Отважному путешественнику Питеру Квиллу попадает в руки таинственный артефакт, принадлежащий могущественному и безжалостному злодею Ронану, строящему коварные планы по захвату Вселенной. Питер оказывается в центре межгалактической охоты, где жертва — он сам.'

# %%
film_info['description'] = '\n'.join(map(attrgetter('text'), desc))
film_info
# Out:
# {'title': 'Стражи Галактики',
#  'title-original': 'Guardians of the Galaxy',
#  'rating': 7.763,
#  'description': 'Отважному путешественнику Питеру Квиллу попадает в руки таинственный артефакт, принадлежащий могущественному и безжалостному злодею Ронану, строящему коварные планы по захвату Вселенной. Питер оказывается в центре межгалактической охоты, где жертва — он сам.\nЕдинственный способ спасти свою жизнь — объединиться с четверкой нелюдимых изгоев: воинственным енотом по кличке Ракета, человекоподобным деревом Грутом, смертельно опасной Гаморой и одержимым жаждой мести Драксом, также известным как Разрушитель. Когда Квилл понимает, какой силой обладает украденный артефакт и какую опасность он представляет для вселенной, одиночка пойдет на все, чтобы сплотить случайных союзников для решающей битвы за судьбу галактики.'}

# %% [markdown]
# ### Извлечем таблицу

# %%
import pandas as pd

# %%
header = soup.find('h3', class_="film-page-section-title")
table = header.next_sibling
rows = table.find_all('div', recursive=False)

len(rows)
# Out:
# 23

# %%
data = []

for row in rows:
    cols = map(lambda x: x.text, row.find_all('div'))
    data.append(cols)

data = pd.DataFrame(data)
data
# Out:
#                     0                                                  1  \
# 0    Год производства                                               2014
# 1              Страна                                                США
# 2                Жанр      фантастика, боевик, приключения, комедияслова
# 3              Слоган  «Мстители спасают лишь Землю бренную, а эти ре...
# 4            Режиссер                                        Джеймс Ганн
# 5            Сценарий       Джеймс Ганн, Николь Перлман, Дэн Абнетт, ...
# 6            Продюсер  Кевин Файги, Виктория Алонсо, Джэми Кристофер,...
# 7            Оператор                                          Бен Дэвис
# 8          Композитор                                       Тайлер Бейтс
# 9            Художник      Чарльз Вуд, Рави Бансал, Мэттью Бродерик, ...
# 10             Монтаж               Фред Раскин, Хьюз Уинборн, Крэйг Вуд
# 11             Бюджет                                       $170 000 000
# 12        Сборы в США                                       $333 176 600
# 13       Сборы в мире                 + $439 600 000 = $772 776 600сборы
# 14            Зрители                          834 тыс , 311.5 тыс , ...
# 15     Сборы в России                                        $37 881 775
# 16  Премьера в Росcии                       31 июля 2014, «WDSSPR»IMAX3D
# 17    Премьера в мире                                  21 июля 2014, ...
# 18       Релиз на DVD          2 декабря 2014, «Уолт Дисней Компани СНГ»
# 19   Релиз на Blu-ray          2 декабря 2014, «Уолт Дисней Компани СНГ»
# 20            Возраст                                                12+
# 21       Рейтинг MPAA         PG-13детям до 13 лет просмотр не желателен
# 22              Время                                   121 мин. / 02:01
#
#                                                     2
# 0                                                None
# 1                                                None
# 2            фантастика, боевик, приключения, комедия
# 3   «Мстители спасают лишь Землю бренную, а эти ре...
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18          2 декабря 2014, «Уолт Дисней Компани СНГ»
# 19          2 декабря 2014, «Уолт Дисней Компани СНГ»
# 20                                               None
# 21                                               None
# 22                                   121 мин. / 02:01

# %% [markdown]
# Пример с таблицей и pandas

# %%
import requests

page = requests.get(
    'https://www.championat.com/football/_russiapl/tournament/2973/statistic/player/bombardir/',
    headers={
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:82.0) Gecko/20100101 Firefox/82.0', 
    },
)
page
# Out:
# <Response [200]>

# %%
pd.read_html(page.text)[0].head()
# Out:
#    Unnamed: 0  Unnamed: 1              Игрок                     Команда  \
# 0           1         NaN       Сердар Азмун                       Зенит
# 1           2         NaN        Артём Дзюба                       Зенит
# 2           3         NaN    Евгений Луценко                     Арсенал
# 3           4         NaN  Александр Соболев  Крылья Советов / Спартак М
# 4           5         NaN      Никола Влашич                        ЦСКА
#
#          Амплуа  \
# 0    нападающий
# 1    нападающий
# 2    нападающий
# 3    нападающий
# 4  полузащитник
#
#    Голы  [{"name":"data"},{"name":"pen"},{"name":"mins"},{"name":"goal","reverse":true},{"name":"days","reverse":true},{"name":"average"},{"name":"game"}]  \
# 0                                                 17
# 1                                                 17
# 2                                                 15
# 3                                                 12
# 4                                                 12
#
#    Пенальти  [{"name":"pen","empty":"first"}]  \
# 0                                           1
# 1                                           7
# 2                                           0
# 3                                           2
# 4                                           2
#
#    Мин./гол  [{"name":"avg_goal","empty":"first"}]  \
# 0                                           123.53
# 1                                           136.18
# 2                                           145.60
# 3                                           184.00
# 4                                           220.92
#
#    Минуты  [{"name":"mins","empty":"first"}]  \
# 0                                       2100
# 1                                       2315
# 2                                       2184
# 3                                       2208
# 4                                       2651
#
#    Игры  [{"name":"game","empty":"first"}]
# 0                                       28
# 1                                       28
# 2                                       28
# 3                                       29
# 4                                       30

# %% [markdown]
# ### Пройдемся по спискам актеров...

# %%
actors, actors_dub = soup.find(class_="film-crew-block").find_all('div', {'data-tid': True})
actors, actors_dub = map(lambda s: s.find('ul'), [actors, actors_dub])

# %%
[row.text for row in actors.children]
# Out:
# ['Крис Пратт',
#  'Зои Салдана',
#  'Дэйв Батиста',
#  'Брэдли Купер',
#  'Вин Дизель',
#  'Ли Пейс',
#  'Майкл Рукер',
#  'Карен Гиллан',
#  'Гленн Клоуз',
#  'Джимон Хонсу']

# %%
[row.text for row in actors_dub.children]
# Out:
# ['Андрей Зайцев',
#  'Мария Цветкова-Овсянникова',
#  'Максим Сергеев',
#  'Сергей Куницкий',
#  'Вин Дизель']

# %% [markdown]
# ### Обкачаем картинки

# %% [markdown]
# https://www.kinopoisk.ru/film/689066/stills/

# %%
soup = BeautifulSoup(open('data/689066_stills_2.html', 'r').read(), 'html.parser')

# %%
list(map(lambda s: s.attrs['src'], soup.find('table', class_='fotos').find_all("img")))[:10]
# Out:
# ['https://st.kp.yandex.net/images/kadr/sm_2802088.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2802087.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2802086.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2802085.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2802084.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2802083.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2802082.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2802081.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2751304.jpg',
#  'https://st.kp.yandex.net/images/kadr/sm_2485201.jpg']

# %% [markdown]
# # О проблемах...

# %% [markdown]
# ## Кодировки

# %%
page = requests.get('https://www.povarenok.ru/recipes/show/163694/')

# %%
print(page.content.decode('utf8')[:315])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-105-6df0923aaa2c> in <module>
# ----> 1 print(page.content.decode('utf8')[:315])
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xca in position 134: invalid continuation byte

# %%
print(page.content.decode('cp1251')[:315])
# Out:
#
#
#   <!DOCTYPE html>
# <html lang="ru">
# <head>
#   <meta http-equiv="Content-Type" content="text/html; charset=windows-1251" />
#   <title>Карамелизированная рыба – кулинарный рецепт</title>
#   <meta name='yandex-verification' content='70aa299668ac52e5' />
#   <meta name="mailru-verification" content="9d7024ca85879691" />

# %%
print(page.text[:315])
# Out:
#
#
#   <!DOCTYPE html>
# <html lang="ru">
# <head>
#   <meta http-equiv="Content-Type" content="text/html; charset=windows-1251" />
#   <title>Карамелизированная рыба – кулинарный рецепт</title>
#   <meta name='yandex-verification' content='70aa299668ac52e5' />
#   <meta name="mailru-verification" content="9d7024ca85879691" />

# %% [markdown]
# <img width='800px' src="https://w3techs.com/diagram/history_overview/character_encoding/ms/y">
#
# https://w3techs.com/technologies/history_overview/character_encoding/ms/y

# %% [markdown]
# Обычно информация о кодировке расположена здесь:
#
# ```html
# <meta http-equiv="Content-Type" content="text/html; charset=windows-1251">
#
# <meta charset="windows-1251">
# ```

# %% [markdown]
# ## Заголовки

# %% [markdown]
# https://www.dafont.com/

# %%
page = requests.get('https://www.dafont.com/')

len(page.content)
# Out:
# 0

# %% [markdown]
# Библиотека для подстановки UserAgent: https://pypi.org/project/fake-useragent/
#
# Что у меня за браузер: https://developers.whatismybrowser.com/useragents/parse/?analyse-my-user-agent=yes

# %%
headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6)'
                         'AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0.1 Safari/605.1.15'}
page = requests.get('https://www.dafont.com/', headers=headers)

len(page.content)
# Out:
# 21491

# %% [markdown]
# ## Cookie

# %% [markdown]
# Cookie (куки) — это небольшие текстовые файлы, в которые браузер записывает данные с посещенных вами сайтов. Файлы cookie позволяют сайтам «запоминать» своих посетителей, например, чтобы каждый раз не переспрашивать их логин и пароль.
#
# chrome://settings/cookies/detail?site=sphere.mail.ru (sessionid_gtp)
#
# https://sphere.mail.ru/people/?q=BD-11

# %%
page = requests.get('https://sphere.mail.ru/people/', params={'q': 'BD-11'})
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser')

table = soup.find('div', class_='people-list')
table is not None
# Out:
# False

# %%
print(page.url)
# Out:
# https://sphere.vk.company/pages/index/?next=/people/%3Fq%3DBD-11#auth

# %%
for page_ in page.history:
    print(page_.status_code, page_.url, sep='\t')

print(page.status_code, page.url, sep='\t')
# Out:
# 301	https://sphere.mail.ru/people/?q=BD-11
# 302	https://sphere.vk.company/people/?q=BD-11
# 302	https://sphere.vk.company/social/after-login/?next=/people/%3Fq%3DBD-11
# 200	https://sphere.vk.company/pages/index/?next=/people/%3Fq%3DBD-11#auth

# %%
with open('sphere-cookies.json', mode='r') as f_cookies:
    cookies = json.load(f_cookies)

page = requests.get('https://sphere.mail.ru/people/', params={'q': 'DS-11'}, cookies=cookies)
page.status_code
# Out:
# 200

# %%
print(page.url)
# Out:
# https://sphere.vk.company/people/?q=DS-11

# %%
soup = BeautifulSoup(page.content, 'html.parser')

table = soup.find('div', class_='people-list')
table is not None
# Out:
# True

# %%
from urllib.parse import urlparse

# %%
rows = table.find('table', class_='table-users').find('tbody').find_all('tr')

users = [{'name': row.find('p', class_='realname').text,
          'nick': urlparse(row.find('p', class_='username').find('a').attrs['href']).\
              path.split('/')[2],
          'type': row.find('span', class_='user-group').text,
          'power': row.find('td', class_='cell-skill').text,
          'rating': row.find('td', class_='cell-rating').text.strip()}
         for row in rows]

df = pd.DataFrame(users)
df.head(10)
# Out:
#                   name             nick           type power rating
# 0          Даниил Роор           d.roor        Студент  0.00   2.52
# 1        Сергей Шадрин        s.shadrin        Студент  0.02   1.26
# 2         Алиса Глушко        a.glushko        Студент  0.00   0.86
# 3   Анастасия Смирнова    anas.smirnova        Студент  0.00   0.86
# 4       Дмитрий Курцев        d.kurtsev        Студент  0.00   0.84
# 5  Екатерина Черкасова     e.cherkasova  Администратор  0.70   0.68
# 6      Мария Кузнецова  mari.kuznetsova        Студент  0.00   0.44
# 7        Кирилл Корбан         k.korban        Студент  0.00   0.42
# 8          Мария Дзюба         m.dziuba        Студент  0.00   0.42
# 9      Никита Долганов      ni.dolganov        Студент  0.00   0.42

# %% [markdown]
# ## Proxy

# %%
def browser_stats_from_yandex(**params):
    page = requests.get('https://yandex.ru/internet/', **params)
    soup = BeautifulSoup(page.content, 'html.parser')

    params = {}
    for e in soup.find('ul', class_='general-info').find_all('li'):
        key = e.find('h3').text
        val = e.find('div', {'class': None})
        val = val.text if val else '–'
        params[key] = val
    return params

# %%
browser_stats_from_yandex()
# Out:
# {'IPv4-адрес': '109.252.155.67',
#  'IPv6-адрес': '–',
#  'Браузер': 'Неизвестный браузер',
#  'Разрешение экрана': '–',
#  'Регион': '–',
#  'JavaScript отключен': 'В вашем браузере отсутствует или выключена поддержка JavaScript.'}

# %% [markdown]
# http://spys.one/proxys/DE/

# %%
proxies = {'http': '82.204.150.190:3129', 'https': '82.204.150.190:3129', }

browser_stats_from_yandex(proxies=proxies)
# Out:
# {'IPv4-адрес': '82.204.150.190',
#  'IPv6-адрес': '–',
#  'Браузер': 'Неизвестный браузер',
#  'Разрешение экрана': '–',
#  'Регион': '–',
#  'JavaScript отключен': 'В вашем браузере отсутствует или выключена поддержка JavaScript.'}

# %%
browser_stats_from_yandex(proxies=proxies, headers={'User-Agent': 'TwitterBot'})

# %% [markdown]
# ## JavaScript

# %% [markdown]
# <img width = '350px' src="images/javascript.jpg">

# %% [markdown]
# https://www.glamour.ru/trends/5-sposobov-nosit-bryuki-chtoby-byt-samoj-modnoj-etoj-vesnoj

# %%
page = requests.get('https://www.glamour.ru/trends/5-sposobov-nosit-bryuki-chtoby-byt-samoj-modnoj-etoj-vesnoj')
page
# Out:
# <Response [200]>

# %%
print(page.text)
# Out:
# <!DOCTYPE html><html lang="ru-RU" data-reactroot=""><head><title>5 способов носить брюки, чтобы быть самой модной этой весной | Glamour</title><meta charSet="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta name="msapplication-tap-highlight" content="no"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="referrer" content="no-referrer-when-downgrade"/><meta name="author" content="Condé Nast"/><meta name="copyright" content="Copyright (c) Condé Nast 2022"/><meta name="description" content="Разбираем самые хитовые брюки весны 2020 и ищем для них эффектные сочетания."/><meta name="id" content="61695eae5b9b848bb4d12002"/><meta name="keywords" content="брюки"/><meta name="news_keywords" content="брюки"/><meta name="robots" content="index, follow, max-image-preview:large"/><meta name="content-type" content="article"/><meta name="parsely-post-id" content="61695eae5b9b848bb4d12002"/><meta name="parsely-metadata" content="{&quot;description&quot;:&quot;Разбираем самые хитовые брюки весны 2020 и ищем для них эффектные сочетания.&quot;,&quot;image-16-9&quot;:&quot;https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_1000,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg&quot;,&quot;image-1-1&quot;:&quot;https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/1:1/w_1000,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg&quot;}"/><meta property="og:description" content="Разбираем самые хитовые брюки весны 2020 и ищем для них эффектные сочетания."/><meta property="og:image" content="https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_1280,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg"/><meta property="og:site_name" content="Glamour"/><meta property="og:title" content="5 способов носить брюки, чтобы быть самой модной этой весной"/><meta property="og:type" content="article"/><meta property="og:url" content="https://www.glamour.ru/trends/5-sposobov-nosit-bryuki-chtoby-byt-samoj-modnoj-etoj-vesnoj"/><meta property="article:content_tier" content="free"/><meta property="article:opinion" content="false"/><meta http-equiv="content-language" content="ru-RU"/><meta property="article:section" content="tags"/><meta property="article:published_time" content="2020-03-26T13:43:00.000Z"/><meta property="twitter:card" content="summary_large_image"/><meta property="twitter:creator" content="@glamour_russia"/><meta property="twitter:description" content="Разбираем самые хитовые брюки весны 2020 и ищем для них эффектные сочетания."/><meta property="twitter:domain" content="https://www.glamour.ru"/><meta property="twitter:image" content="https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_1280,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg?mbid=social_retweet"/><meta property="twitter:site" content="@glamour_russia"/><meta property="twitter:title" content="5 способов носить брюки, чтобы быть самой модной этой весной"/><meta property="fb:app_id" content="2868534929934855"/><meta property="fb:pages" content="145853866916"/><link rel="canonical" href="https://www.glamour.ru/trends/5-sposobov-nosit-bryuki-chtoby-byt-samoj-modnoj-etoj-vesnoj"/><style data-styled="" data-styled-version="5.3.1">.daKEJa{display:inline-block;background-color:rgba(151,141,135,1);cursor:pointer;text-align:center;-webkit-text-decoration:none;text-decoration:none;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .daKEJa:disabled{pointer-events:none;}/*!sc*/
# .daKEJa:hover,.daKEJa:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# data-styled.g1[id="BaseButton-aWfgy"]{content:"daKEJa,"}/*!sc*/
# .ehNcSS{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:1;border-radius:0px;padding:1rem;min-width:auto;height:auto;min-height:auto;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;color:rgba(255,255,255,1);border-color:rgba(54,52,50,1);border-width:2px;border-style:solid;background-color:rgba(54,52,50,1);--type-token:utility.button-utility;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1428571428571428em;font-size:14px;font-weight:600;overflow-wrap:normal;}/*!sc*/
# .ehNcSS.button--utility + .ButtonWrapper-dOcxiw.button--utility{margin-top:1rem;}/*!sc*/
# .ehNcSS.button__icon--chevron-down .button-icon{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .ehNcSS.button__icon--chevron-up .button-icon{-webkit-transform:rotate(270deg);-ms-transform:rotate(270deg);transform:rotate(270deg);}/*!sc*/
# @media (min-width:768px){.ehNcSS{min-width:auto;}}/*!sc*/
# .ehNcSS:hover{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ehNcSS:focus{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ehNcSS:focus-visible{outline:3px solid #0066cc;outline-offset:3px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ehNcSS:active{outline:none;}/*!sc*/
# .ehNcSS:active.ButtonWrapper-dOcxiw:active{border-color:rgba(0,0,0,0.2);}/*!sc*/
# .ehNcSS:active::before{position:absolute;z-index:-1;width:100%;height:100%;content:'';}/*!sc*/
# .ehNcSS:active{outline:none;}/*!sc*/
# .ehNcSS:hover{color:rgba(255,255,255,1);border-color:rgba(44,55,129,1);border-width:2px;border-style:solid;background-color:rgba(44,55,129,1);}/*!sc*/
# .ehNcSS:focus{color:rgba(255,255,255,1);border-color:rgba(54,52,50,1);border-width:2px;border-style:solid;background-color:rgba(54,52,50,1);}/*!sc*/
# .ehNcSS:active{color:rgba(255,255,255,1);border-color:rgba(44,55,129,1);border-width:2px;border-style:solid;background-color:rgba(44,55,129,1);}/*!sc*/
# .ehNcSS:disabled{color:rgba(255,255,255,1);border-color:rgba(151,141,135,1);border-width:2px;border-style:solid;background-color:rgba(151,141,135,1);}/*!sc*/
# .cRuTwD{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;z-index:1;border-radius:0px;padding:0 1rem;min-width:2.5rem;height:50px;min-height:0;-webkit-transition-property:color,background,border;transition-property:color,background,border;-webkit-transition-duration:200ms;transition-duration:200ms;-webkit-transition-timing-function:ease-in;transition-timing-function:ease-in;color:rgba(54,52,50,1);border-color:rgba(255,255,255,1);border-width:2px;border-style:solid;background-color:rgba(255,255,255,1);--type-token:utility.button-utility;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1428571428571428em;font-size:14px;font-weight:600;overflow-wrap:normal;}/*!sc*/
# .cRuTwD.button--utility + .ButtonWrapper-dOcxiw.button--utility{margin-top:1rem;}/*!sc*/
# .cRuTwD.button__icon--chevron-down .button-icon{-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# .cRuTwD.button__icon--chevron-up .button-icon{-webkit-transform:rotate(270deg);-ms-transform:rotate(270deg);transform:rotate(270deg);}/*!sc*/
# @media (min-width:768px){.cRuTwD{min-width:10rem;}}/*!sc*/
# .cRuTwD:hover{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .cRuTwD:focus{outline:none;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .cRuTwD:focus-visible{outline:3px solid #0066cc;outline-offset:3px;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .cRuTwD:active{outline:none;}/*!sc*/
# .cRuTwD:active.ButtonWrapper-dOcxiw:active{border-color:rgba(0,0,0,0.2);}/*!sc*/
# .cRuTwD:active::before{position:absolute;z-index:-1;background:rgba(0,0,0,0.2);width:100%;height:100%;content:'';}/*!sc*/
# .cRuTwD:active{outline:none;}/*!sc*/
# .cRuTwD:hover{color:rgba(255,255,255,1);border-color:rgba(44,55,129,1);border-width:2px;border-style:solid;background-color:rgba(44,55,129,1);}/*!sc*/
# .cRuTwD:focus{color:rgba(54,52,50,1);border-color:rgba(255,255,255,1);border-width:2px;border-style:solid;background-color:rgba(255,255,255,1);}/*!sc*/
# .cRuTwD:active{color:rgba(255,255,255,1);border-color:rgba(44,55,129,1);border-width:2px;border-style:solid;background-color:rgba(44,55,129,1);}/*!sc*/
# .cRuTwD:disabled{color:rgba(151,141,135,1);border-color:rgba(116,108,102,1);border-width:2px;border-style:solid;background-color:rgba(116,108,102,1);}/*!sc*/
# data-styled.g2[id="ButtonWrapper-dOcxiw"]{content:"ehNcSS,cRuTwD,"}/*!sc*/
# .eTnxrM{font-variant-ligatures:none;padding:0.5rem 0;position:absolute;margin:0;border:0;padding:0;width:1px;height:1px;overflow:hidden;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);white-space:nowrap;}/*!sc*/
# .kgbwGm{font-variant-ligatures:none;padding:0.5rem 0;}/*!sc*/
# data-styled.g3[id="ButtonLabel-eBwykR"]{content:"eTnxrM,kgbwGm,"}/*!sc*/
# .kugeta{padding-right:0;padding-left:0;}/*!sc*/
# data-styled.g4[id="ButtonIconWrapper-ivrAUv"]{content:"kugeta,"}/*!sc*/
# .iYceZt{display:block;width:32px;height:32px;}/*!sc*/
# data-styled.g5[id="ButtonIcon-iWCKZc"]{content:"iYceZt,"}/*!sc*/
# {/*! normalize.scss v0.1.0 | MIT License | based on git.io/normalize */}/*!sc*/
# html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%;}/*!sc*/
# body{margin:0;}/*!sc*/
# article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section,summary{display:block;}/*!sc*/
# audio,canvas,progress,video{display:inline-block;vertical-align:baseline;}/*!sc*/
# audio:not([controls]){display:none;height:0;}/*!sc*/
# [hidden],template{display:none;}/*!sc*/
# a{background-color:transparent;}/*!sc*/
# a:active,a:hover{outline:0;}/*!sc*/
# abbr[title]{border-bottom:1px dotted;}/*!sc*/
# b,strong{font-weight:bold;}/*!sc*/
# dfn{font-style:italic;}/*!sc*/
# h1{font-size:2em;margin:0.67em 0;}/*!sc*/
# mark{background:#ff0;color:#000;}/*!sc*/
# small{font-size:80%;}/*!sc*/
# sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline;}/*!sc*/
# sup{top:-0.5em;}/*!sc*/
# sub{bottom:-0.25em;}/*!sc*/
# img{border:0;}/*!sc*/
# svg:not(:root){overflow:hidden;}/*!sc*/
# figure{margin:1em 40px;}/*!sc*/
# hr{-moz-box-sizing:content-box;box-sizing:content-box;height:0;}/*!sc*/
# pre{overflow:auto;}/*!sc*/
# code,kbd,pre,samp{font-family:monospace,monospace;font-size:1em;}/*!sc*/
# button,input,optgroup,select,textarea{color:inherit;font:inherit;margin:0;}/*!sc*/
# button{overflow:visible;}/*!sc*/
# button,select{text-transform:none;}/*!sc*/
# button,html input[type="button"],input[type="reset"],input[type="submit"]{-webkit-appearance:button;cursor:pointer;}/*!sc*/
# button[disabled],html input[disabled]{cursor:default;}/*!sc*/
# button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0;}/*!sc*/
# input{line-height:normal;}/*!sc*/
# input[type="checkbox"],input[type="radio"]{box-sizing:border-box;padding:0;}/*!sc*/
# input[type="number"]::-webkit-inner-spin-button,input[type="number"]::-webkit-outer-spin-button{height:auto;}/*!sc*/
# input[type="search"]{-webkit-appearance:textfield;-moz-box-sizing:content-box;-webkit-box-sizing:content-box;box-sizing:content-box;}/*!sc*/
# input[type="search"]::-webkit-search-cancel-button,input[type="search"]::-webkit-search-decoration{-webkit-appearance:none;}/*!sc*/
# fieldset{border:1px solid #c0c0c0;margin:0 2px;padding:0.35em 0.625em 0.75em;}/*!sc*/
# legend{border:0;padding:0;}/*!sc*/
# textarea{overflow:auto;}/*!sc*/
# optgroup{font-weight:bold;}/*!sc*/
# table{border-collapse:collapse;border-spacing:0;}/*!sc*/
# td,th{padding:0;}/*!sc*/
# *{box-sizing:border-box;}/*!sc*/
# html{height:100%;font-size:16px;}/*!sc*/
# body{margin:0;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;}/*!sc*/
# body{--type-token:consumptionEditorial.body-core;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.5555555555555556em;font-size:18px;font-weight:400;overflow-wrap:normal;height:100%;min-height:100%;-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;}/*!sc*/
# .page{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding-top:3.5rem;min-height:100vh;}/*!sc*/
# .stackednavigation-site-navigation .page{padding-top:3.5rem;}/*!sc*/
# @media (min-width:1024px){.stackednavigation-site-navigation .page{padding-top:11rem;}}/*!sc*/
# @media (min-width:1024px){.stackednavigation-site-navigation .page.page-hero-ad-hidden,.stackednavigation-site-navigation .page.page-theme-inverted{padding-top:7rem;}}/*!sc*/
# .siteheader-site-navigation .page{padding-top:0;}/*!sc*/
# @media (min-width:1024px){.siteheader-site-navigation .page .grid-layout__aside .sticky-box{top:8rem;}}/*!sc*/
# @media (min-width:1024px){.fixed-header-with-link-banner-nav-variation .page.page-theme-inverted{padding-top:7.75rem;}}/*!sc*/
# .cns-ads-slot-state-empty{display:none;}/*!sc*/
# @media (min-width:320px){.cns-ads-slot-type-hero{min-height:50 + 32px;}}/*!sc*/
# @media (min-width:768px){.cns-ads-slot-type-hero{min-height:50 + 32px;}}/*!sc*/
# @media (min-width:320px){.cns-ads-slot-state-filled.cns-ads-slot-type-hero{background-color:rgba(255,255,255,1);padding:8px 0;}}/*!sc*/
# @media (min-width:768px){.cns-ads-slot-state-filled.cns-ads-slot-type-hero{background-color:rgba(255,255,255,1);padding:8px 0;}}/*!sc*/
# .page-theme-inverted .ad__slot--hero,.page-theme-inverted .cns-ads-slot-state-filled.cns-ads-slot-type-hero{background-color:rgba(35,31,32,1);}/*!sc*/
# .page-theme-special .ad__slot--hero,.page-theme-special .cns-ads-slot-state-filled.cns-ads-slot-type-hero{background-color:rgba(40,48,114,1);}/*!sc*/
# .page .cns-ads-slot-type-footer{padding:2.5rem 0;}/*!sc*/
# .ad--footer{background-color:rgba(255,255,255,1);}/*!sc*/
# .ad--mid-content{position:relative;background-color:rgba(255,255,255,1);padding:2.5rem 0;}/*!sc*/
# .ad--mid-content .cns-ads-slot-size-9x1,.ad--mid-content .cns-ads-slot-size-9x2{z-index:80;}/*!sc*/
# @media (min-width:768px){.ad--mid-content{padding:2.5rem 0;}}/*!sc*/
# .ad--mid-content .ad-label{--type-token:globalEditorial.ad-label;text-transform:uppercase;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.15em;-moz-letter-spacing:0.15em;-ms-letter-spacing:0.15em;letter-spacing:0.15em;line-break:auto;line-height:1.2em;font-size:10px;font-weight:400;overflow-wrap:normal;display:block;position:absolute;top:0.25rem;right:0;left:0;text-align:center;text-transform:uppercase;color:rgba(116,108,102,1);}/*!sc*/
# @media (min-width:320px){.ad--mid-content .ad-label{top:1.6rem;}}/*!sc*/
# @media (min-width:768px){.ad--mid-content .ad-label{top:1.6rem;}}/*!sc*/
# .ad--in-content{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .ad--in-content .ad__slot{width:85%;max-width:575px;}/*!sc*/
# .ad--in-content .ad-label{--type-token:globalEditorial.ad-label;text-transform:uppercase;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.15em;-moz-letter-spacing:0.15em;-ms-letter-spacing:0.15em;letter-spacing:0.15em;line-break:auto;line-height:1.2em;font-size:10px;font-weight:400;overflow-wrap:normal;display:block;text-align:center;text-transform:uppercase;color:rgba(116,108,102,1);}/*!sc*/
# .grid + .row-mid-content-ad .ad--mid-content{z-index:300;margin-top:-0.5rem;margin-bottom:2rem;}/*!sc*/
# .ad-stickyhero{top:0;z-index:300;}/*!sc*/
# .ad-stickyhero.ad-stickyhero-issticky{position:-webkit-sticky;position:sticky;top:56px;z-index:400;background-color:rgba(255,255,255,1);}/*!sc*/
# .ad-stickyhero.ad-stickyhero-issticky.with-link-banner{top:116px;}/*!sc*/
# @media (max-width:768px){.ad-stickyhero.ad-stickyhero-issticky.with-link-banner{top:116px;}}/*!sc*/
# .siteheader-site-navigation .ad-stickyhero.ad-stickyhero-issticky{top:0;}/*!sc*/
# .ad-stickyhero.ad-stickyhero-sticky-animating{-webkit-transition:-webkit-transform 1s ease;-webkit-transition:transform 1s ease;transition:transform 1s ease;}/*!sc*/
# .ad-stickyhero.ad-stickyhero-sticky-visible{-webkit-transform:translateY(0);-ms-transform:translateY(0);transform:translateY(0);}/*!sc*/
# .ad-stickyhero.ad-stickyhero-sticky-50{-webkit-transform:translateY(-160px);-ms-transform:translateY(-160px);transform:translateY(-160px);}/*!sc*/
# .ad-stickyhero.ad-stickyhero-sticky-90{-webkit-transform:translateY(-240px);-ms-transform:translateY(-240px);transform:translateY(-240px);}/*!sc*/
# .ad-stickyhero.ad-stickyhero-sticky-250{-webkit-transform:translateY(-560px);-ms-transform:translateY(-560px);transform:translateY(-560px);}/*!sc*/
# .ad-stickyhero .ad-stickyhero-button{position:absolute;right:0;z-index:100;margin:0 0.75rem 0 auto;border:0;background-color:transparent;padding:0;width:1.5rem;}/*!sc*/
# @media (min-width:320px){.ad-stickyhero .ad-stickyhero-button{display:none;}}/*!sc*/
# @media (min-width:768px){.ad-stickyhero .ad-stickyhero-button{display:block;top:10px;margin:0 1.25rem 0 1rem;}}/*!sc*/
# .ad-stickyhero .ad-stickyhero-button:hover,.ad-stickyhero .ad-stickyhero-button:focus{border:0;background-color:transparent;}/*!sc*/
# .ad-stickyhero .ad-stickyhero-button:hover svg path,.ad-stickyhero .ad-stickyhero-button:focus svg path{fill:rgba(44,55,129,1);}/*!sc*/
# .ad-stickyhero .ad-stickyhero-button .ButtonIconWrapper-ivrAUv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:100%;max-width:1.4rem;height:100%;}/*!sc*/
# .ad-stickyhero .ad-stickyhero-button svg path{fill:rgba(54,52,50,1);}/*!sc*/
# @media print{.ad{display:none;}}/*!sc*/
# input[type='submit'],button{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:inline-block;--background-color__token-name:colors.interactive.base.light;background-color:rgba(151,141,135,1);text-align:center;-webkit-text-decoration:none;text-decoration:none;border:0;}/*!sc*/
# input[type='submit']:hover,button:hover,input[type='submit']:focus,button:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# input[type='checkbox']:checked + label::after{opacity:1;}/*!sc*/
# input[type='checkbox']:disabled + label{opacity:0.5;}/*!sc*/
# input[type='checkbox'].checkbox__invalid + label,input[type='checkbox']:invalid + label{--color__token-name:colors.interactive.base.black;color:rgba(54,52,50,1);}/*!sc*/
# input[type='checkbox'].checkbox__invalid + label::before,input[type='checkbox']:invalid + label::before{border:1px solid;--border-color__token-name:colors.interactive.base.invalid-primary;border-color:rgba(175,29,38,1);background-color:rgba( 247,205,207, 0.15 );}/*!sc*/
# input[type='checkbox'].checkbox__invalid + label::after,input[type='checkbox']:invalid + label::after{opacity:1;}/*!sc*/
# input[type='checkbox'] + label{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# input[type='checkbox'] + label:hover::before,input[type='checkbox'] + label:focus::before{--border-color__token-name:colors.interactive.base.black;border-color:rgba(54,52,50,1);}/*!sc*/
# input[type='checkbox'] + label::before{display:block;position:relative;content:'';margin-right:0.5em;border-width:1px;border-style:solid;height:1.5em;--border-color__token-name:colors.interactive.base.black;border-color:rgba(54,52,50,1);width:1.5em;}/*!sc*/
# input[type='checkbox'] + label::after{display:block;position:absolute;content:'';top:0.9em;left:0.75em;-webkit-transform:translateX(-50%) translateY(-50%);-ms-transform:translateX(-50%) translateY(-50%);transform:translateX(-50%) translateY(-50%);opacity:0;content:'✔︎';-webkit-transition-property:all;transition-property:all;-webkit-transition-duration:0.25s;transition-duration:0.25s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# input[type='checkbox'].checkbox--switch:checked + label::after{-webkit-transform:translateX(1.1em) translateY(-50%);-ms-transform:translateX(1.1em) translateY(-50%);transform:translateX(1.1em) translateY(-50%);opacity:1;--background-color__token-name:colors.interactive.base.white;background-color:rgba(255,255,255,1);}/*!sc*/
# input[type='checkbox'].checkbox--switch + label:hover::before,input[type='checkbox'].checkbox--switch + label:focus::before{--border-color__token-name:colors.interactive.base.black;border-color:rgba(54,52,50,1);}/*!sc*/
# input[type='checkbox'].checkbox--switch + label::before{margin-right:0.5em;border-width:1px;border-style:solid;height:1.5em;--border-color__token-name:colors.interactive.base.black;border-color:rgba(54,52,50,1);border-radius:1em;width:3em;}/*!sc*/
# input[type='checkbox'].checkbox--switch + label::after{display:block;position:absolute;content:'';top:0.87em;left:0.75em;-webkit-transform:translateX(-50%) translateY(-50%);-ms-transform:translateX(-50%) translateY(-50%);transform:translateX(-50%) translateY(-50%);opacity:1;border:0;border-radius:50%;--background-color__token-name:colors.interactive.base.light;background-color:rgba(151,141,135,1);width:0.999em;height:0.999em;-webkit-transition-property:background-color,-webkit-transform;-webkit-transition-property:background-color,transform;transition-property:background-color,transform;-webkit-transition-duration:0.3s;transition-duration:0.3s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# input[type='radio']:checked + label::after{opacity:1;}/*!sc*/
# input[type='radio']:disabled + label{opacity:0.5;}/*!sc*/
# input[type='radio'] + label{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# input[type='radio'] + label:hover::before,input[type='radio'] + label:focus::before{--border-color__token-name:colors.interactive.base.black;border-color:rgba(54,52,50,1);}/*!sc*/
# input[type='radio'] + label::before{display:block;position:relative;content:'';margin-right:0.5em;border:1px solid;--border-color__token-name:colors.interactive.base.dark;border-color:rgba(116,108,102,1);border-radius:50%;--background-color__token-name:colors.interactive.base.white;background-color:rgba(255,255,255,1);width:1.5em;height:1.5em;}/*!sc*/
# input[type='radio'] + label::after{display:block;position:absolute;content:'';top:0.87em;left:0.795em;-webkit-transform:translateX(-50%) translateY(-50%);-ms-transform:translateX(-50%) translateY(-50%);transform:translateX(-50%) translateY(-50%);opacity:0;border-radius:50%;--background-color__token-name:colors.interactive.base.white;background-color:rgba(255,255,255,1);width:0.999em;height:0.999em;-webkit-transition-property:all;transition-property:all;-webkit-transition-duration:0.25s;transition-duration:0.25s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# fieldset{margin:0;border:0;padding:0;}/*!sc*/
# input{border:1px solid;--border-color__token-name:colors.interactive.base.black;border-color:rgba(54,52,50,1);padding:0.125em 0.5rem;}/*!sc*/
# input[disabled]{pointer-events:none;}/*!sc*/
# input[type='checkbox'],input[type='radio']{position:absolute;top:0;right:0;bottom:0;left:0;visibility:initial;opacity:0;margin:0;cursor:inherit;padding:0;width:100%;height:100%;}/*!sc*/
# input[type='submit']{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:inline-block;--background-color__token-name:colors.interactive.base.light;background-color:rgba(151,141,135,1);text-align:center;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# input[type='submit']:hover,input[type='submit']:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# input[type='reset']{cursor:pointer;}/*!sc*/
# input[type='number']::-webkit-inner-spin-button,input[type='number']::-webkit-outer-spin-button{height:auto;}/*!sc*/
# input[type='search']{box-sizing:border-box;}/*!sc*/
# select{border:1px solid;--border-color__token-name:colors.interactive.base.black;border-color:rgba(54,52,50,1);padding:0.125em 0.5rem;width:auto;}/*!sc*/
# textarea{border:1px solid;--border-color__token-name:colors.interactive.base.black;border-color:rgba(54,52,50,1);padding:0.125em 0.5rem;display:block;width:100%;max-width:25em;}/*!sc*/
# img{max-width:100%;height:auto;vertical-align:bottom;}/*!sc*/
# a{cursor:pointer;--color__token-name:colors.interactive.base.light;color:rgba(151,141,135,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;}/*!sc*/
# table{width:100%;}/*!sc*/
# td{padding:0.5em;vertical-align:bottom;text-align:left;vertical-align:baseline;}/*!sc*/
# th{padding:0.5em;vertical-align:bottom;text-align:left;vertical-align:bottom;}/*!sc*/
# thead{--border-color__token-name:colors.foundation.menu.dividers;border-color:rgba(237,189,193,1);border-width:0 0 2px 0;border-style:solid;}/*!sc*/
# tfoot{--border-color__token-name:colors.foundation.menu.dividers;border-color:rgba(237,189,193,1);border-width:2px 0 0 0;border-style:solid;}/*!sc*/
# tbody tr{--border-color__token-name:colors.foundation.menu.dividers;border-color:rgba(237,189,193,1);border-width:0 0 1px 0;border-style:solid;}/*!sc*/
# tbody tr:nth-of-type(even){background-color:rgba( 237,189,193, 0.5 );}/*!sc*/
# tbody td{--border-color__token-name:colors.foundation.menu.dividers;border-color:rgba(237,189,193,1);border-width:1px 0 0 0;border-style:solid;}/*!sc*/
# tbody td:last-of-type{border-right:0;}/*!sc*/
# data-styled.g8[id="sc-global-dQbJuQ1"]{content:"sc-global-dQbJuQ1,"}/*!sc*/
# @media (max-width:767px){.dPlIkM::before{content:'';display:block;padding-top:100%;width:100%;}}/*!sc*/
# @media (min-width:768px){.dPlIkM::before{content:'';display:block;padding-top:56.25%;width:100%;}}/*!sc*/
# .dPlIkM > .aspect-ratio--overlay-container{bottom:0;left:0;overflow:hidden;position:absolute;right:0;top:0;pointer-events:none;}/*!sc*/
# data-styled.g12[id="AspectRatioContainer-dgQA-Dr"]{content:"dPlIkM,"}/*!sc*/
# .fArnhQ{display:inline-block;position:relative;}/*!sc*/
# data-styled.g13[id="ResponsiveImagePicture-jIKgcS"]{content:"fArnhQ,"}/*!sc*/
# .bTiaWs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:100%;height:100%;}/*!sc*/
# .bTiaWs .icon{width:100%;height:100%;}/*!sc*/
# data-styled.g15[id="SocialIconContainer-fbhAuK"]{content:"bTiaWs,"}/*!sc*/
# .gXsNTP{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:3rem;height:3rem;}/*!sc*/
# .gXsNTP:hover,.gXsNTP:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gXsNTP .icon path{--fill__token-name:colors.interactive.social.primary;fill:rgba(44,55,129,1);}/*!sc*/
# .gXsNTP:hover .icon .icon-bookmark--activated-checkmark-stroke{--fill__token-name:colors.interactive.base.white;fill:rgba(255,255,255,1);-webkit-transition:all 0.2s ease-in-out;transition:all 0.2s ease-in-out;}/*!sc*/
# .gXsNTP:hover .icon-bookmark.icon path{--fill__token-name:colors.interactive.base.white;fill:rgba(255,255,255,1);}/*!sc*/
# .gXsNTP:hover .icon path,.gXsNTP:hover .icon-bookmark--activated.icon path{--fill__token-name:colors.interactive.social.primary-hover;fill:rgba(247,205,207,1);}/*!sc*/
# .codZaz{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:3rem;height:3rem;--background__token-name:colors.interactive.social.primary;background:rgba(44,55,129,1);}/*!sc*/
# .codZaz:hover,.codZaz:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .codZaz path{--fill__token-name:colors.interactive.social.secondary;fill:rgba(255,255,255,1);}/*!sc*/
# .codZaz:hover{background: --colors.interactive.social.primary-hover__token-name:undefined;colors.interactive.social.primary-hover:null;}/*!sc*/
# .codZaz:hover path{--fill__token-name:colors.interactive.social.secondary-hover;fill:rgba(255,255,255,1);}/*!sc*/
# .cwLycP{-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:3rem;height:3rem;}/*!sc*/
# .cwLycP:hover,.cwLycP:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .cwLycP path{--fill__token-name:colors.foundation.footer.links.primary;fill:rgba(255,255,255,1);}/*!sc*/
# .cwLycP:hover path{--fill__token-name:colors.foundation.footer.social.hover;fill:rgba(247,205,207,1);}/*!sc*/
# data-styled.g16[id="SocialIconExternalLink-gugldc"]{content:"gXsNTP,codZaz,cwLycP,"}/*!sc*/
# .ijYSfG{padding-left:1rem;false;}/*!sc*/
# .kGgUZg{padding-left:1rem;}/*!sc*/
# data-styled.g17[id="SocialIconsListItem-hYmGVl"]{content:"ijYSfG,kGgUZg,"}/*!sc*/
# .kKiupF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin-top:0;margin-bottom:0;margin-left:-1rem;padding-left:0;list-style:none;}/*!sc*/
# .cRFtOR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin-top:0;margin-bottom:0;margin-left:-1rem;padding-left:0;list-style:none;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-left:-2rem;}/*!sc*/
# @media (min-width:1024px){.cRFtOR{-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;}}/*!sc*/
# data-styled.g18[id="SocialIconsList-NTOMk"]{content:"kKiupF,cRFtOR,"}/*!sc*/
# .lmzbhe{false;}/*!sc*/
# @media (min-width:320px){.lmzbhe{-webkit-box-pack:start;-webkit-justify-content:start;-ms-flex-pack:start;justify-content:start;}}/*!sc*/
# data-styled.g19[id="SocialIconsWrapper-ixWYBx"]{content:"eavmKn,lmzbhe,"}/*!sc*/
# .ffpsoz .icon-bookmark path{-webkit-transition:all 0.2s ease-in-out;transition:all 0.2s ease-in-out;}/*!sc*/
# data-styled.g20[id="SocialIconNetworkIconComponent-ktcJhn"]{content:"ffpsoz,"}/*!sc*/
# .eTiIvU{margin:0;}/*!sc*/
# data-styled.g21[id="BaseWrap-sc-TURhJ"]{content:"eTiIvU,"}/*!sc*/
# .hONBCw{--type-token:utility.assistive-text;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1428571428571428em;font-size:14px;font-weight:400;overflow-wrap:normal;color:rgba(116,108,102,1);}/*!sc*/
# .hONBCw a{color:inherit;}/*!sc*/
# .WtCSp{--type-token:consumptionEditorial.body-core;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.5555555555555556em;font-size:18px;font-weight:400;overflow-wrap:normal;color:rgba(151,141,135,1);}/*!sc*/
# .WtCSp a{color:inherit;}/*!sc*/
# .jPtstq{--type-token:foundation.title-primary;text-transform:uppercase;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.14999999783255838em;-moz-letter-spacing:0.14999999783255838em;-ms-letter-spacing:0.14999999783255838em;letter-spacing:0.14999999783255838em;line-break:auto;line-height:1.4545454545454546em;font-size:11px;font-weight:600;overflow-wrap:normal;color:rgba(54,52,50,1);}/*!sc*/
# .jPtstq a{color:inherit;}/*!sc*/
# .hvBvta{--type-token:consumptionEditorial.hed-standard;text-transform:none;font-family:SangBleuKingdom ,Georgia,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1333333333333333em;font-size:30px;font-weight:500;overflow-wrap:normal;color:rgba(54,52,50,1);}/*!sc*/
# @media (min-width:768px){.hvBvta{font-size:48px;line-height:1.0833333333333333em;}}/*!sc*/
# @media (min-width:1024px){.hvBvta{font-size:48px;line-height:1.0833333333333333em;}}/*!sc*/
# .hvBvta a{color:inherit;}/*!sc*/
# .iFKery{--type-token:globalEditorial.context-tertiary;text-transform:uppercase;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:0.14999999783255838em;-moz-letter-spacing:0.14999999783255838em;-ms-letter-spacing:0.14999999783255838em;letter-spacing:0.14999999783255838em;line-break:auto;line-height:1.4545454545454546em;font-size:11px;font-weight:400;overflow-wrap:normal;color:rgba(54,52,50,1);}/*!sc*/
# .iFKery a{color:inherit;}/*!sc*/
# .iTOLFh{--type-token:globalEditorial.context-secondary;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.3333333333333333em;font-size:12px;font-weight:400;overflow-wrap:normal;color:rgba(54,52,50,1);}/*!sc*/
# .iTOLFh a{color:inherit;}/*!sc*/
# .iiXwoX{--type-token:discovery.hed-core-primary;text-transform:none;font-family:SangBleuKingdom ,Georgia,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1818181818181819em;font-size:22px;font-weight:500;overflow-wrap:normal;color:rgba(54,52,50,1);}/*!sc*/
# @media (min-width:768px){.iiXwoX{font-size:21px;line-height:1.2380952380952381em;}}/*!sc*/
# .iiXwoX a{color:inherit;}/*!sc*/
# .jWYvXM{--type-token:consumptionEditorial.body-core;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.5555555555555556em;font-size:18px;font-weight:400;overflow-wrap:normal;color:rgba(54,52,50,1);}/*!sc*/
# .jWYvXM a{color:inherit;}/*!sc*/
# .fCYAft{--type-token:globalEditorial.numerical-small;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1em;font-size:16px;font-weight:600;overflow-wrap:normal;color:rgba(54,52,50,1);}/*!sc*/
# .fCYAft a{color:inherit;}/*!sc*/
# .gDgZVc{--type-token:globalEditorial.tags;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1428571428571428em;font-size:14px;font-weight:600;overflow-wrap:normal;color:rgba(116,108,102,1);}/*!sc*/
# .gDgZVc a{color:inherit;}/*!sc*/
# .fDWudf{--type-token:globalEditorial.tags;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1428571428571428em;font-size:14px;font-weight:600;overflow-wrap:normal;color:rgba(54,52,50,1);}/*!sc*/
# .fDWudf a{color:inherit;}/*!sc*/
# data-styled.g22[id="BaseText-fFzBQt"]{content:"hONBCw,WtCSp,jPtstq,hvBvta,iFKery,iTOLFh,iiXwoX,jWYvXM,fCYAft,gDgZVc,fDWudf,"}/*!sc*/
# .kouJfX{color:rgba(151,141,135,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;color:rgba(54,52,50,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kouJfX:link{-webkit-text-decoration:underline;text-decoration:underline;color:rgba(54,52,50,1);}/*!sc*/
# .kouJfX:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(54,52,50,1);}/*!sc*/
# .kouJfX:hover{color:rgba(54,52,50,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .kouJfX:active{color:rgba(54,52,50,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .kouJfX:focus{color:rgba(54,52,50,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .kouJfX:active,.kouJfX:link,.kouJfX:visited{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kouJfX:hover,.kouJfX:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hHyfuQ{color:rgba(151,141,135,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;--type-token:foundation.link-primary;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1428571428571428em;font-size:14px;font-weight:600;overflow-wrap:normal;color:rgba(54,52,50,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hHyfuQ:link{-webkit-text-decoration:underline;text-decoration:underline;color:rgba(54,52,50,1);}/*!sc*/
# .hHyfuQ:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(54,52,50,1);}/*!sc*/
# .hHyfuQ:hover{color:rgba(40,48,114,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hHyfuQ:active{color:rgba(40,48,114,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hHyfuQ:focus{color:rgba(40,48,114,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hHyfuQ:active,.hHyfuQ:link,.hHyfuQ:visited{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hHyfuQ:hover,.hHyfuQ:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .fKRifg{color:rgba(151,141,135,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;--type-token:foundation.link-primary;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.1428571428571428em;font-size:14px;font-weight:600;overflow-wrap:normal;color:rgba(54,52,50,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fKRifg:link{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(54,52,50,1);}/*!sc*/
# .fKRifg:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(54,52,50,1);}/*!sc*/
# .fKRifg:hover{color:rgba(40,48,114,1);-webkit-text-decoration:inherit;text-decoration:inherit;}/*!sc*/
# .fKRifg:active{color:rgba(40,48,114,1);-webkit-text-decoration:inherit;text-decoration:inherit;}/*!sc*/
# .fKRifg:focus{color:rgba(40,48,114,1);-webkit-text-decoration:inherit;text-decoration:inherit;}/*!sc*/
# .fKRifg:active,.fKRifg:link,.fKRifg:visited{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fKRifg:hover,.fKRifg:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .gHLSEF{color:rgba(151,141,135,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;--type-token:foundation.link-feature;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1em;font-size:32px;font-weight:600;overflow-wrap:normal;color:rgba(54,52,50,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gHLSEF:link{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(54,52,50,1);}/*!sc*/
# .gHLSEF:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(54,52,50,1);}/*!sc*/
# .gHLSEF:hover{color:rgba(40,48,114,1);-webkit-text-decoration:inherit;text-decoration:inherit;}/*!sc*/
# .gHLSEF:active{color:rgba(40,48,114,1);-webkit-text-decoration:inherit;text-decoration:inherit;}/*!sc*/
# .gHLSEF:focus{color:rgba(40,48,114,1);-webkit-text-decoration:inherit;text-decoration:inherit;}/*!sc*/
# .gHLSEF:active,.gHLSEF:link,.gHLSEF:visited{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gHLSEF:hover,.gHLSEF:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .dRUEny{color:rgba(151,141,135,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;color:rgba(54,52,50,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dRUEny:link{-webkit-text-decoration:underline;text-decoration:underline;color:rgba(54,52,50,1);}/*!sc*/
# .dRUEny:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(54,52,50,1);}/*!sc*/
# .dRUEny:hover{color:rgba(44,55,129,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .dRUEny:active{color:rgba(44,55,129,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .dRUEny:focus{color:rgba(44,55,129,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .dRUEny:active,.dRUEny:link,.dRUEny:visited{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dRUEny:hover,.dRUEny:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .ikHQHl{color:rgba(151,141,135,1);-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:5s;transition-duration:5s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;--type-token:utility.input-core;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.4300000326974052em;font-size:14px;font-weight:400;overflow-wrap:normal;color:rgba(255,255,255,1);cursor:pointer;-webkit-transition-property:color,background,text-shadow;transition-property:color,background,text-shadow;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-in-out;transition-timing-function:ease-in-out;cursor:pointer;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ikHQHl:link{-webkit-text-decoration:underline;text-decoration:underline;color:rgba(255,255,255,1);}/*!sc*/
# .ikHQHl:visited{-webkit-text-decoration:inherit;text-decoration:inherit;color:rgba(255,255,255,1);}/*!sc*/
# .ikHQHl:hover{color:rgba(255,255,255,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .ikHQHl:active{color:rgba(255,255,255,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .ikHQHl:focus{color:rgba(255,255,255,1);-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .ikHQHl:active,.ikHQHl:link,.ikHQHl:visited{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ikHQHl:hover,.ikHQHl:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# ...
# data-styled.g1183[id="MultiPackageBaseRow-iwuYBt"]{content:"eLoWFJ,"}/*!sc*/
# .hFrYYW{margin-top:3.5rem;margin-bottom:3.5rem;}/*!sc*/
# @media (min-width:1024px){.RowWrapper-egDQBE.homepage__half-column-row + .hFrYYW.hFrYYW{width:50%;max-width:800px;}.RowWrapper-egDQBE.homepage__half-column-row + .hFrYYW.hFrYYW .SectionTitleHed-hZJayd{--type-token:discovery.subhed-section-secondary;text-transform:none;font-family:Inter ,Helvetica Neue,Helvetica,sans-serif;font-feature-settings:normal;font-style:normal;-webkit-letter-spacing:normal;-moz-letter-spacing:normal;-ms-letter-spacing:normal;letter-spacing:normal;line-break:auto;line-height:1.2727272727272727em;font-size:22px;font-weight:600;overflow-wrap:normal;}.homepage__half-column-row + .hFrYYW.hFrYYW > .SummaryCollageOneGridWithMargin-fvWQTC{padding-left:var(--grid-gap);}.hFrYYW .SummaryRiverSection-knvNOm{margin:0 auto;max-width:1600px;}}/*!sc*/
# data-styled.g1185[id="MultiPackageRow-dRSwkr"]{content:"hFrYYW,"}/*!sc*/
# </style><style id="font-faces">@font-face {font-family: Inter;font-weight: 400;font-style: normal;font-display: swap;src: url("/verso/static/assets/fonts/inter-v3-latin_cyrillic-regular.woff2") format("woff2"), url("/verso/static/assets/fonts/inter-v3-latin_cyrillic-regular.woff") format("woff"); }@font-face {font-family: Inter;font-weight: 600;font-style: normal;font-display: swap;src: url("/verso/static/assets/fonts/inter-v3-latin_cyrillic-600.woff2") format("woff2"), url("/verso/static/assets/fonts/inter-v3-latin_cyrillic-600.woff") format("woff"); }@font-face {font-family: Inter;font-weight: 900;font-style: normal;font-display: swap;src: url("/verso/static/assets/fonts/inter-v3-latin_cyrillic-900.woff2") format("woff2"), url("/verso/static/assets/fonts/inter-v3-latin_cyrillic-900.woff") format("woff"); }@font-face {font-family: SangBleuKingdom;font-weight: 500;font-style: normal;font-display: swap;src: url("/verso/static/assets/fonts/SangBleuKingdom-Medium.woff2") format("woff2"), url("/verso/static/assets/fonts/SangBleuKingdom-Medium.woff") format("woff"); }@font-face {font-family: SangBleuKingdom;font-weight: 500;font-style: italic;font-display: swap;src: url("/verso/static/assets/fonts/SangBleuKingdom-MediumItalic.woff2") format("woff2"), url("/verso/static/assets/fonts/SangBleuKingdom-MediumItalic.woff") format("woff"); }</style><link rel="shortcut icon" href="https://www.glamour.ru/verso/static/glamour-ru/assets/favicon.ico" type="image/x-icon"/><link rel="preconnect" href="https://polyfill.io"/><style></style><link rel="preload" as="image" href="https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_2560,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg" imagesrcset="https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_120,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 120w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_240,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 240w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_320,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 320w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_640,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 640w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_960,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 960w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_1280,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 1280w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_1600,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 1600w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_1920,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 1920w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_2240,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 2240w" imagesizes="100vw" media="(min-width: 768px)" /><link rel="preload" as="image" href="https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/1:1/w_1024,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg" imagesrcset="https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/1:1/w_120,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 120w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/1:1/w_240,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 240w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/1:1/w_320,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 320w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/1:1/w_640,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 640w, https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/1:1/w_960,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg 960w" imagesizes="100vw" media="(max-width: 767px)" /><style></style><link rel="amphtml" href="https://www.glamour.ru/trends/5-sposobov-nosit-bryuki-chtoby-byt-samoj-modnoj-etoj-vesnoj/amp"/><script type="text/javascript">
#           window.cns = window.cns || {}; window.cns.pageContext = {"channel":"fashion","content":{"copyCount":294,"imageCount":6,"embedCount":1,"ratio":42},"contentType":"article","keywords":{"copilotid":["61695eae5b9b848bb4d12002"],"platform":["verso"],"tags":["pants","trends","embedded-gallery","_flyway","_flyway:source:article:1a358abbbf804704aeca9b4b285975ad","_migrated:id:67171","_migrated:adultContent:false","_migrated:active:true","_migrated:slug:5-sposobov-nosit-bryuki-chtoby-byt-samoj-modnoj-etoj-vesnoj","_migrated:checkerByCorrector:true","_migrated:checkedByEditor:false","_migrated:privateContent:false","_migrated:bestBefore:null"]},"server":"production","slug":"5-sposobov-nosit-bryuki-chtoby-byt-samoj-modnoj-etoj-vesnoj","subChannel":"trends","subSubChannel":"","templateType":"mt_article_two_column"};
#         </script><script></script><link rel="preconnect" href="https://securepubads.g.doubleclick.net"><script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" id="gpt-script" async></script><script>window.googletag = window.googletag || {cmd: []}</script>
#         <script src="https://z.moatads.com/condenastheader559028685182/moatheader.js" async></script>
#       <script>window.cns=window.cns||{};window.cns.queue=window.cns.queue||[];window.cns.async=function(s,c){cns.queue.push({service:s,callback:c})};window.sparrowQueue=window.sparrowQueue||[];</script><script id="cns-head-include">!function(){"use strict";var n={exports:{}};!function(n,t){var r=function(){var n=0;function t(n){var t=[],r=0,i=0;this.push=function(s){r-i>=n&&++i>=n&&(i=0,r=n-1),t[r%n]=s,r++},this.asArray=function(){var s=t.slice(i,Math.min(r,n)),u=t.slice(0,Math.max(r-n,0));return s.concat(u)},this.list=t}function r(t,r){for(var i=r,s=0;s<t.length;s++){var u=t[s],a=i.r;a[u]||(a[u]={w:u,r:{},i:n++}),i=a[u]}return i}function i(n,t,r){var i;return r[n]?i=r[n]:(i=function(n,t){for(var r=[[t,0]],i={},s=[];r.length;){var u=r.shift(),a=u[0],o=u[1],e=a.r,f=n[o];if(void 0===f&&a.fn&&!i[a.i]?(i[a.i]=1,s.push(a.fn)):e[f]&&r.push([e[f],o+1]),e["#"])for(var h=o;h<=n.length;h++)r.push([e["#"],h]);f&&e["*"]&&r.push([e["*"],o+1])}return s}(n.split("."),t),r[n]=i),i}var s=function(){var s={w:"",r:{},i:n++},u={},a=new t(9999);function o(n,t){var i=r(n.split("."),s),a=i.fn||[];return a.push(t),i.fn=a,u={},function(){var n=a.indexOf(t);n>-1&&a.splice(n,1)}}function e(n,t){var r=Date.now();a.push([n,r]);for(var o=i(n,s,u),e={topic:n},f=0;f<o.length;f++)for(var h=o[f],c=0;c<h.length;c++)h[c](t,e)}this.emit=e,this.on=o,this.history=function(t){var s={w:"",r:{},i:n++};r(t.split("."),s).fn=1;for(var u=[],o={},e=a.asArray(),f=0;f<e.length;f++){var h=e[f];i(h[0],s,o).length&&u.push(h)}return u},this.publish=e,this.subscribe=o};return s.Ring=t,s}();n.exports=r}(n);var t=n.exports;window.cnBus=window.cnBus||new t,window.cns=window.cns||{};const r=window.cns;r.fastAdsHead="6.57.1",r.timing=r.timing||{},r.timing.headerStart=Date.now(),r.queue=r.queue||[],r.flags={}}();
# </script><script></script><script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","articleBody":"\n\n[#image: /photos/61695eb09dc22985f213965d]\n\nБлагодаря фантазии дизайнеров и модниц брюки в новом сезоне становятся главным объектом экспериментов — этой весной девушки заправляют их в высокие сапоги и ботинки на грубой подошве, оборачивают шнурками от обуви и носят с подтяжками. Редакторы Glamour.ru вместе с основательницей бренда I AM Studio Дарьей Самкович разобрались, как носить разные модели брюк, чтобы следующие полгода быть самой модной.\n\n[#image: /photos/61695eaf40145cb55cc551f5]|||Дарья Самкович|||\n\n> Брюки-бананы\n\n[#image: /photos/61695eb08b907e73d406256b]\n\nОдни из самых актуальных моделей этого сезона — это брюки-бананы и галифе. Такой фасон подойдет не только для офисных будней. Дополнив образ укороченным свитером или водолазкой, высокими сапогами или казаками, можно отправиться на встречу с подругами или романтическую прогулку по городу. Главное — заправить брюки в обувь. Создать вечерний образ помогут босоножки на завязках, топ на тонких бретелях и жакет с широкими плечами.\n\n> Брюки клеш\n\n[#image: /photos/61695eb13fb701eb6f71b9e8]\n\nТакие брюки, пожалуй, — самый универсальный вариант. Они отлично сочетаются с удлиненными жакетами, вечерними топами и объемными свитерами. Заправляйте в брюки клеш рубашки с коротким рукавом, носите их с трикотажными водолазками, кожаными куртками, пальто и плащами, подбирайте к ним ковбойские казаки или универсальные белые кеды.\n\n> Прямые брюки со стрелками\n\n[#image: /photos/61695eb2f4f05bc21a939779]\n\nПрямые брюки со стрелками в стиле буржуазных 70-х комбинируйте с маскулинными вещами. Классические лоферы и длинный объемный тренч отлично дополнят образ и придадут ему винтажного шика. Или дополните брюки мужскими подтяжками, предварительно щегольски подвернув штанины.\n\n> Широкие брюки\n\n[#gallery: /galleries/61695eb229475b112097e346]\n\nЛетящие брюки-палаццо зрительно вытянут силуэт. Эта модель будет отлично смотреться в составе бежевого тотал-лука. Песочные брюки, водолазка цвета карамели и бежевое пальто — интеллектуальный и выдержанный образ, который никого не оставит равнодушным.\n\n> Широкие кожаные брюки\n\n[#image: /photos/61695eb1854ef439051b41fe]\n\nВ этом весенне-летнем сезоне набирают популярность кожаные брюки свободного силуэта. Такие брюки черного, карамельного и оливкового цветов можно сочетать с белой футболкой, рубашкой с коротким рукавом, флисовой курткой или плащом. И да, советуем сделать ставку на экстремально длинную модель — пусть брючины немного волочатся по полу.\n\nФото: Getty Images","articleSection":"мода","dateModified":"2020-03-26T16:43:00.000+03:00","datePublished":"2020-03-26T16:43:00.000+03:00","headline":"5 способов носить брюки, чтобы быть самой модной этой весной","image":["https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/5:7/w_1285,h_1799,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg","https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/16:9/w_2700,h_1519,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg","https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/4:3/w_2400,h_1800,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg","https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/1:1/w_1800,h_1800,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg","https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/3:4/w_1350,h_1800,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg","https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/2:3/w_1200,h_1800,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg","https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/3:2/w_2700,h_1800,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg"],"keywords":["тенденции","брюки","web"],"thumbnailUrl":"https://media.glamour.ru/photos/61695eaf7f0d5d1447f095c8/3:2/w_2700,h_1800,c_limit/D38D5EB2-1A5E-4B33-8F68-5E379E7F2979.jpeg","url":"https://www.glamour.ru/trends/5-sposobov-nosit-bryuki-chtoby-byt- ...
# </span></div></figure><div class="AdWrapper-fFweuL dIvDeZ ad ad--in-content"><div class="ad__slot ad__slot--in-content" data-node-id="ci67eq"></div></div><blockquote class="BlockquoteEmbedWrapper-sc-eQzYHb liXogw blockquote-embed"><div class="BlockquoteEmbedContent-hqqZro jMzPJT blockquote-embed__content"><p>Брюки-бананы</p></div></blockquote><figure class="AssetEmbedWrapper-iLfYbx iclJOW asset-embed"><div class="AssetEmbedAssetContainer-fogSSF kRpSOB asset-embed__asset-container"><span class="SpanWrapper-kGGzGm fCMktE responsive-asset AssetEmbedResponsiveAsset-eqsnW ehcXJi asset-embed__responsive-asset"><picture class="ResponsiveImagePicture-jIKgcS fArnhQ AssetEmbedResponsiveAsset-eqsnW ehcXJi asset-embed__responsive-asset responsive-image"><noscript><img alt="5 способов носить брюки чтобы быть самой модной этой весной" class="ResponsiveImageContainer-dlOMGF dnUTOP responsive-image__image" src="https://media.glamour.ru/photos/61695eb08b907e73d406256b/master/w_1600%2Cc_limit/GettyImages-1210746708.jpg" srcSet="https://media.glamour.ru/photos/61695eb08b907e73d406256b/master/w_120,c_limit/GettyImages-1210746708.jpg 120w, https://media.glamour.ru/photos/61695eb08b907e73d406256b/master/w_240,c_limit/GettyImages-1210746708.jpg 240w, https://media.glamour.ru/photos/61695eb08b907e73d406256b/master/w_320,c_limit/GettyImages-1210746708.jpg 320w, https://media.glamour.ru/photos/61695eb08b907e73d406256b/master/w_640,c_limit/GettyImages-1210746708.jpg 640w, https://media.glamour.ru/photos/61695eb08b907e73d406256b/master/w_960,c_limit/GettyImages-1210746708.jpg 960w, https://media.glamour.ru/photos/61695eb08b907e73d406256b/master/w_1280,c_limit/GettyImages-1210746708.jpg 1280w, https://media.glamour.ru/photos/61695eb08b907e73d406256b/master/w_1600,c_limit/GettyImages-1210746708.jpg 1600w" sizes="100vw"/></noscript></picture></span></div></figure></div></div></div><div class="GridItem-buSdEM gKfJBS grid--item grid-layout__aside"><div class="StickyBoxWrapper-euhCxU luKJG sticky-box"><div class="StickyBoxPrimary-fEgDcn dFVkFO sticky-box__primary"><div class="Container-imGeBO ftlPuP"></div><div class="AdWrapper-fFweuL dIvDeZ ad ad--rail"><div class="ad__slot ad__slot--rail" data-node-id="9wh76d"></div></div><div class="ConsumerMarketingUnitThemedWrapper-kkMeXf hBFNZw consumer-marketing-unit consumer-marketing-unit--display-rail" role="presentation" aria-hidden="true"><div class="consumer-marketing-unit__slot consumer-marketing-unit__slot--display-rail"></div><div class="journey-unit"></div></div><div data-attr-viewport-monitor="" class="RecircMostPopularWrapper-laeRwu btOzvW recirc-most-popular-wrapper viewport-monitor-anchor"></div></div><div class="StickyBoxPlaceholder-jNQMsI laMCLq"></div></div></div></div><div class="RowWrapper-egDQBE hVsKfd full-bleed-ad row-mid-content-ad"><div class="AdWrapper-fFweuL dIvDeZ ad ad--mid-content"><div class="ad__slot ad__slot--mid-content" data-node-id="ol7uyh"></div></div></div><div class="GridWrapper-vNBSO jMumET grid grid-margins grid-items-2 ArticlePageChunksGrid-kRgPDq DBpfE grid-layout--adrail narrow wide-adrail"><div class="GridItem-buSdEM PibmB grid--item grid-layout__content"><div class="BodyWrapper-ctnerm dgcqzg body body__container article__body" data-journey-hook="client-content" data-testid="BodyWrapper"><div class="body__inner-container"><p>Одни из самых актуальных моделей этого сезона — это брюки-бананы и галифе. Такой фасон подойдет не только для офисных будней. Дополнив образ укороченным свитером или водолазкой, высокими сапогами или казаками, можно отправиться на встречу с подругами или романтическую прогулку по городу. Главное — заправить брюки в обувь. Создать вечерний образ помогут босоножки на завязках, топ на тонких бретелях и жакет с широкими плечами.</p><blockquote class="BlockquoteEmbedWrapper-sc-eQzYHb liXogw blockquote-embed"><div class="BlockquoteEmbedContent-hqqZro jMzPJT blockquote-embed__content"><p>Брюки клеш</p></div></blockquote><figure class="AssetEmbedWrapper-iLfYbx icl ...
# </script><script src="/hotzones/src/pixelpropagate.js?cb=10229" async></script><script></script></body></html>

# %% [markdown]
# ### Selenium
#
# <img width = '500px' src="https://www.nutraingredients.com/var/wrbm_gb_food_pharma/storage/images/_aliases/wrbm_large/publications/food-beverage-nutrition/nutraingredients.com/news/research/selenium-may-protect-against-epileptic-seizures-mouse-study-suggests/7690019-1-eng-GB/Selenium-may-protect-against-epileptic-seizures-mouse-study-suggests.jpg">
#
# http://selenium-python.readthedocs.io/
#
# https://kreisfahrer.gitbooks.io/selenium-webdriver/

# %%
from selenium import webdriver

import html
from time import sleep

# %%
with webdriver.Firefox() as driver:
    sleep(10)
    driver.get("https://mail.ru/")
    sleep(3)

# %%
with webdriver.Firefox() as driver:
    sleep(10)
    
    driver.get('https://www.glamour.ru/beauty-news/kunzhutnoe-moloko-novinki-dlya-lica-ot-erborian')
    sleep(1)

    title = driver.find_element_by_tag_name('h1').text
    
    # description = driver.find_element_by_xpath('//div[@itemprop="description"]').text
    description = driver.find_element_by_xpath('//div[@data-testid="ContentHeaderAccreditation"]').text

    image = driver.find_element_by_xpath('//meta[@property="og:image"]').get_attribute('content')
    
    rubric = (e.text for e in driver.find_elements_by_class_name('article-detail-top__info-line'))
    rubric = list(filter(None, map(str.lower, rubric)))

    tags = (e.text for e in driver.find_elements_by_xpath('//ul[@class="tag-list__list"]//a[@itemprop="name"]'))
    tags = list(filter(None, map(str.lower, tags)))
    
    info = {
        'title': title,
        'description': description,
        'tags': tags,
        'rubric': rubric,
        'preview': image,
    }
    
info
# Out:
# {'title': 'Кунжутное молоко: новинки для лица от Erborian',
#  'description': 'А также приятная акция!\n27 МАРТА 2020 Г.',
#  'tags': [],
#  'rubric': [],
#  'preview': 'https://media.glamour.ru/photos/61695ea69dc22985f213964f/16:9/w_1280,c_limit/89744560_248315309519574_3644042830260352040_n.jpg'}

# %% [markdown]
# ### А как можно решить эту задачу по-умному?

# %% [markdown]
# Идем в консольку браузера 😉

# %%
url_raw = 'https://www.glamour.ru/beauty-news/kunzhutnoe-moloko-novinki-dlya-lica-ot-erborian'

url = urlparse(url_raw).path.rsplit('/', 1)[-1]
url = 'https://api.glamour.ru/article/' + url

page = requests.get(url)
    
tree = page.json()
tree
# Out:
# {'id': 67190,
#  'name': 'Кунжутное молоко: новинки для лица от Erborian',
#  'name_formatted': 'Кунжутное молоко: новинки для&nbsp;лица от&nbsp;Erborian',
#  'preview_image': {'id': 573934,
#   'name': '89744560_248315309519574_3644042830260352040_n.jpg',
#   'width': 1080,
#   'height': 1079,
#   'preview_url': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/78feb0e0/o/w200',
#   'urls': {'16:9': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/307a1a1f/c1079x607x0x297/w2000',
#    '4:3': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/ecdf2f2d/c1080x810x0x135/w2000',
#    '3:2': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/488cb464/c1080x720x0x180/w2000',
#    '1:1': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/116b5db0/c1079x1079x1x0/w2000'},
#   'render_parameters': {'16:9': {'parameters': 'c1079x607x0x297',
#     'ratio': '16:9'},
#    '4:3': {'parameters': 'c1080x810x0x135', 'ratio': '4:3'},
#    '3:2': {'parameters': 'c1080x720x0x180', 'ratio': '3:2'},
#    '1:1': {'parameters': 'c1079x1079x1x0', 'ratio': '1:1'}},
#   'tag_elements': [],
#   'searchable': False,
#   'credit': None},
#  'tags': [],
#  'tag_elements': [{'id': 233998,
#    'tag': {'id': 829, 'name': 'Erborian', 'comment': '', 'slug': 'erborian'},
#    'sort': 2},
#   {'id': 233999,
#    'tag': {'id': 1833,
#     'name': 'маска для лица',
#     'comment': '',
#     'slug': 'face-mask'},
#    'sort': 1},
#   {'id': 234000,
#    'tag': {'id': 2428, 'name': 'пилинг', 'comment': '', 'slug': 'peeling'},
#    'sort': 0}],
#  'published_at': '2020-03-27T16:30:00+03:00',
#  'active': True,
#  'guid': 'e75404d9b77d4163b83a15c0438256e1',
#  'slug': 'kunzhutnoe-moloko-novinki-dlya-lica-ot-erborian',
#  'main_tag': {'id': 23613,
#   'name': 'Бьюти новости',
#   'comment': '',
#   'slug': 'beauty-news'},
#  'private_content': False,
#  'photo_source': None,
#  'printed_issue': None,
#  'authors': [],
#  'related_materials': [],
#  'promoted': False,
#  'partner': None,
#  'partner_type': None,
#  'id_old': None,
#  'adult_content': False,
#  'meta_title': None,
#  'meta_description': None,
#  'meta_keywords': None,
#  'og_title': None,
#  'og_description': None,
#  'og_image': None,
#  'preview_text': 'А также приятная акция!',
#  'content': {'blocks': [{'type': 'image',
#     'fields': [{'name': 'file', 'fields': [{'name': 'id', 'value': 573935}]},
#      {'name': 'caption', 'value': None},
#      {'name': 'link', 'value': None},
#      {'name': 'text', 'value': None}],
#     'display_type': 'horizontal'},
#    {'type': 'text',
#     'fields': [{'name': 'text',
#       'value': 'Звездным компонентом новой линейки марки стало кунжутное молоко, получаемое из семян корейского кунжута. В кулинарных традициях Востока кунжут особенно ценится и используется повсеместно из-за высокого содержания белков, жирных кислот, минералов и витаминов. А в составе средств он отвечает за выравнивание рельефа и текстуры кожи, уменьшение шелушения и сухости. \n\nВ новой линейке представлены два средства: очищающий бальзам и маска. Кунжутное молоко усиливают действие натуральные питательных и смягчающих ингредиентов в формуле — комплекса 7 трав, кунжутного масла и масла семян подсолнечника. И никаких сульфатов, парабенов и минеральных масел.'}],
#     'display_type': 'default'},
#    {'type': 'quote',
#     'fields': [{'name': 'text',
#       'value': '**Разглаживающий бальзам-пилинг «Кунжутное молоко»**'}],
#     'display_type': 'inset'},
#    {'type': 'text',
#     'fields': [{'name': 'text',
#       'value': 'Это мягкое очищающее средство 2 в 1 удалит загрязнения и макияж и одновременно обеспечит деликатный пилинг. Маслянистый бальзам очищает поры, разглаживает кожу и выравнивает тон, делая цвет лица более свежим. В ответе за эффект — комплекс отшелушивающих энзимов для удаления ороговевших клеток и кунжутного молока для улучшения микрорельефа кожи. А травяной комплекс успокаивает кожу и обладает антиоксидантными свойствами.\n\n**Цена:** 75 мл — 2790 руб.; 30 мл — 1190 руб.'}],
#     'display_type': 'default'},
#    {'type': 'image',
#     'fields': [{'name': 'file', 'fields': [{'name': 'id', 'value': 573932}]},
#      {'name': 'caption', 'value': None},
#      {'name': 'link', 'value': None},
#      {'name': 'text', 'value': None}],
#     'display_type': 'horizontal'},
#    {'type': 'quote',
#     'fields': [{'name': 'text',
#       'value': '**Разглаживающая маска-пилинг «Кунжутное молоко»**'}],
#     'display_type': 'inset'},
#    {'type': 'text',
#     'fields': [{'name': 'text',
#       'value': 'Нанесите кремовую маску тонким слоем на сухую кожу, через пять минут помассируйте и только потом смойте водой. Энзимы мягко отшелушивают, а питательное кунжутное масло, богатое  жирными кислотами, увлажняет, укрепляет кожный барьер и способствует обновлению кожи, обеспечивая ей питание  и комфорт без чувства стянутости. \n\n**Цена:** 2790 руб.'}],
#     'display_type': 'default'},
#    {'type': 'image',
#     'fields': [{'name': 'file', 'fields': [{'name': 'id', 'value': 573933}]},
#      {'name': 'caption', 'value': None},
#      {'name': 'link', 'value': None},
#      {'name': 'text', 'value': None}],
#     'display_type': 'horizontal'},
#    {'type': 'text',
#     'fields': [{'name': 'text',
#       'value': 'Приобрести эти новинки и другие средства марки сейчас можно со скидкой 30 %! Скидка действует в интернет-магазине до 31 марта, распространяется на весь ассортимент, кроме travel-форматов, аксессуаров и товаров по специальным ценам. Приятный бонус — подарки за покупки! При любой покупке от 1000 рублей можно получить мягкую маску для сна, а от 6000 рублей — крем для рук с эффектом BB-крема и тканевые патчи Glow для сияющего взгляда.'}],
#     'display_type': 'text_with_border'}]},
#  'formatted_content': {'blocks': [{'type': 'banner-placeholder-top'},
#    {'type': 'image',
#     'content': {'image': {'id': 573935,
#       'name': '89744560_248315309519574_3644042830260352040_n.jpg',
#       'width': 1080,
#       'height': 1079,
#       'preview_url': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/78feb0e0/o/w200',
#       'urls': {'16:9': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/bda3673b/c1080x608x0x236/w2000',
#        '4:3': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/ecdf2f2d/c1080x810x0x135/w2000',
#        '3:2': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/488cb464/c1080x720x0x180/w2000',
#        '1:1': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/116b5db0/c1079x1079x1x0/w2000'},
#       'render_parameters': {'16:9': {'parameters': 'c1080x608x0x236',
#         'ratio': '16:9'},
#        '4:3': {'parameters': 'c1080x810x0x135', 'ratio': '4:3'},
#        '3:2': {'parameters': 'c1080x720x0x180', 'ratio': '3:2'},
#        '1:1': {'parameters': 'c1079x1079x1x0', 'ratio': '1:1'}},
#       'tag_elements': [],
#       'searchable': False,
#       'credit': None},
#      'caption': None,
#      'link': None,
#      'display_type': 'horizontal'}},
#    {'type': 'text',
#     'content': {'text': 'Звездным компонентом новой линейки марки стало кунжутное молоко, получаемое из&nbsp;семян корейского кунжута. В&nbsp;кулинарных традициях Востока кунжут особенно ценится и&nbsp;используется повсеместно из-за&nbsp;высокого содержания белков, жирных кислот, минералов и&nbsp;витаминов. А&nbsp;в&nbsp;составе средств он отвечает за&nbsp;выравнивание рельефа и&nbsp;текстуры кожи, уменьшение шелушения и&nbsp;сухости. \n\nВ новой линейке представлены два средства: очищающий бальзам и&nbsp;маска. Кунжутное молоко усиливают действие натуральные питательных и&nbsp;смягчающих ингредиентов в&nbsp;формуле&nbsp;— комплекса 7&nbsp;трав, кунжутного масла и&nbsp;масла семян подсолнечника. И&nbsp;никаких сульфатов, парабенов и&nbsp;минеральных масел.',
#      'display_type': 'default'}},
#    {'type': 'banner-placeholder-middle'},
#    {'type': 'quote',
#     'content': {'quote': '**Разглаживающий бальзам-пилинг «Кунжутное молоко»**',
#      'display_type': 'inset',
#      'inset': []}},
#    {'type': 'text',
#     'content': {'text': 'Это мягкое очищающее средство 2&nbsp;в 1&nbsp;удалит загрязнения и&nbsp;макияж и&nbsp;одновременно обеспечит деликатный пилинг. Маслянистый бальзам очищает поры, разглаживает кожу и&nbsp;выравнивает тон, делая цвет лица более свежим. В&nbsp;ответе за&nbsp;эффект&nbsp;— комплекс отшелушивающих энзимов для&nbsp;удаления ороговевших клеток и&nbsp;кунжутного молока для&nbsp;улучшения микрорельефа кожи. А&nbsp;травяной комплекс успокаивает кожу и&nbsp;обладает антиоксидантными свойствами.\n\n**Цена:** 75&nbsp;мл&nbsp;— 2790&nbsp;руб.; 30&nbsp;мл&nbsp;— 1190&nbsp;руб.',
#      'display_type': 'default'}},
#    {'type': 'banner-placeholder-interscroller'},
#    {'type': 'image',
#     'content': {'image': {'id': 573932,
#       'name': 'Очищающий бальзам-пилинг Кунжутное молоко 30 мл.png',
#       'width': 1200,
#       'height': 1200,
#       'preview_url': 'https://condenast-media.gcdn.co/glamour/0720c50b1dd79482160607edc2f24651.png/8336e6e8/o/w200',
#       'urls': {'16:9': 'https://condenast-media.gcdn.co/glamour/0720c50b1dd79482160607edc2f24651.png/ed7f96b8/c1200x675x0x263/w2000',
#        '4:3': 'https://condenast-media.gcdn.co/glamour/0720c50b1dd79482160607edc2f24651.png/c5dc0f20/c1200x900x0x150/w2000',
#        '3:2': 'https://condenast-media.gcdn.co/glamour/0720c50b1dd79482160607edc2f24651.png/50943e6b/c1200x800x0x200/w2000',
#        '1:1': 'https://condenast-media.gcdn.co/glamour/0720c50b1dd79482160607edc2f24651.png/63b5c0f2/c1200x1200x0x0/w2000'},
#       'render_parameters': {'16:9': {'parameters': 'c1200x675x0x263',
#         'ratio': '16:9'},
#        '4:3': {'parameters': 'c1200x900x0x150', 'ratio': '4:3'},
#        '3:2': {'parameters': 'c1200x800x0x200', 'ratio': '3:2'},
#        '1:1': {'parameters': 'c1200x1200x0x0', 'ratio': '1:1'}},
#       'tag_elements': [],
#       'searchable': False,
#       'credit': None},
#      'caption': None,
#      'link': None,
#      'display_type': 'horizontal'}},
#    {'type': 'quote',
#     'content': {'quote': '**Разглаживающая маска-пилинг «Кунжутное молоко»**',
#      'display_type': 'inset',
#      'inset': []}},
#    {'type': 'text',
#     'content': {'text': 'Нанесите кремовую маску тонким слоем на&nbsp;сухую кожу, через&nbsp;пять минут помассируйте и&nbsp;только потом смойте водой. Энзимы мягко отшелушивают, а&nbsp;питательное кунжутное масло, богатое  жирными кислотами, увлажняет, укрепляет кожный барьер и&nbsp;способствует обновлению кожи, обеспечивая ей питание и&nbsp;комфорт без&nbsp;чувства стянутости. \n\n**Цена:** 2790&nbsp;руб.',
#      'display_type': 'default'}},
#    {'type': 'image',
#     'content': {'image': {'id': 573933,
#       'name': 'Разглаживающая маска-пилинг Кунжутное молоко 60 г коробка.png',
#       'width': 1200,
#       'height': 1200,
#       'preview_url': 'https://condenast-media.gcdn.co/glamour/bedb789e37046c77e2b787010a910e6b.png/1290e0e4/o/w200',
#       'urls': {'16:9': 'https://condenast-media.gcdn.co/glamour/bedb789e37046c77e2b787010a910e6b.png/63b3b5ba/c1200x675x0x263/w2000',
#        '4:3': 'https://condenast-media.gcdn.co/glamour/bedb789e37046c77e2b787010a910e6b.png/785ff917/c1200x900x0x150/w2000',
#        '3:2': 'https://condenast-media.gcdn.co/glamour/bedb789e37046c77e2b787010a910e6b.png/cc1e9300/c1200x800x0x200/w2000',
#        '1:1': 'https://condenast-media.gcdn.co/glamour/bedb789e37046c77e2b787010a910e6b.png/13960740/c1200x1200x0x0/w2000'},
#       'render_parameters': {'16:9': {'parameters': 'c1200x675x0x263',
#         'ratio': '16:9'},
#        '4:3': {'parameters': 'c1200x900x0x150', 'ratio': '4:3'},
#        '3:2': {'parameters': 'c1200x800x0x200', 'ratio': '3:2'},
#        '1:1': {'parameters': 'c1200x1200x0x0', 'ratio': '1:1'}},
#       'tag_elements': [],
#       'searchable': False,
#       'credit': None},
#      'caption': None,
#      'link': None,
#      'display_type': 'horizontal'}},
#    {'type': 'text',
#     'content': {'text': 'Приобрести эти новинки и&nbsp;другие средства марки сейчас можно со скидкой 30 %! Скидка действует в&nbsp;интернет-магазине до&nbsp;31&nbsp;марта, распространяется на&nbsp;весь ассортимент, кроме travel-форматов, аксессуаров и&nbsp;товаров по&nbsp;специальным ценам. Приятный бонус&nbsp;— подарки за&nbsp;покупки! При&nbsp;любой покупке от&nbsp;1000&nbsp;рублей можно получить мягкую маску для&nbsp;сна, а&nbsp;от 6000&nbsp;рублей&nbsp;— крем для&nbsp;рук с&nbsp;эффектом BB-крема и&nbsp;тканевые патчи Glow для&nbsp;сияющего взгляда.',
#      'display_type': 'text_with_border'}}]},
#  'detail_image': None,
#  'content_changed_at': '2021-09-24T12:58:09+03:00',
#  'verstka': False,
#  'verstka_desktop_content': None,
#  'verstka_mobile_content': None,
#  'type': 'article',
#  'amp_url': 'https://amp.glamour.ru/beauty-news/kunzhutnoe-moloko-novinki-dlya-lica-ot-erborian'}

# %%
title = tree['name']

description = tree['preview_text']

image = tree['preview_image']['preview_url']

rubric = [tree['main_tag']['name']]
rubric = list(filter(None, map(str.lower, rubric)))

tags = (r['tag']['name'] for r in tree['tag_elements'])
tags = list(filter(None, map(str.lower, tags)))

info = {
    'title': title,
    'description': description,
    'tags': tags,
    'rubric': rubric,
    'preview': image,
}

info
# Out:
# {'title': 'Кунжутное молоко: новинки для лица от Erborian',
#  'description': 'А также приятная акция!',
#  'tags': ['erborian', 'маска для лица', 'пилинг'],
#  'rubric': ['бьюти новости'],
#  'preview': 'https://condenast-media.gcdn.co/glamour/a083be49c45d768932c3f5a0c5be7d52.jpg/78feb0e0/o/w200'}

# %% [markdown]
# ### А что ещё умеет Selenium?

# %%
import random

def random_sleep(offset=1.5, length=4):
    sleep(random.random() * length + offset)

with webdriver.Firefox() as driver:
    sleep(12)
    
    driver.get("https://music.yandex.ru/artist/184100")
    random_sleep()
    
    # можно исполнять свой javascript код
    driver.execute_script("window.scrollTo(0, 250);")
    random_sleep(0)
    
    # можно использовать CSS-селекторы или XPath
    # лучше использовать Firefox, он лучше подсказывает пути
    # стоит использовать, если путь выглядит лаконичным
    # пример плохого CSS-селектора
    elem = driver.find_element_by_css_selector(
        'div.d-tabs__tab:nth-child(3) > a:nth-child(1)')
    
    # можно кликать по объектам
    # [ переходим на страничку с альбомами группы ]
    elem.click()
    random_sleep()
    
    # можно искать по классам
    albums = driver.find_element_by_class_name('page-artist__albums').\
        find_elements_by_class_name('album_selectable')
    album = albums[3]
    # [ прокручиваем до нужного альбома ]
    driver.execute_script("return arguments[0].scrollIntoView();", album)
    random_sleep()
    # [ переходим на страничку с выбранным альбомом ]
    album.find_element_by_class_name('d-link').click()
    random_sleep()
    
    driver.execute_script("window.scrollTo(0, 340);")
    random_sleep(0)
    
    # [ кликаем на play ]
    play = driver.find_element_by_class_name('button-play__type_album')
    play.click()
    
    # [ прокликиваем на 3 трек ]
    # пример хорошего CSS-селектора
    next_ = driver.find_element_by_css_selector('.d-icon_track-next')
    for i in range(2):
        next_.click()
        random_sleep(1, 1)
        
    # [ выводим информацию о треке ]
    # пример хорошего CSS-селектора
    elem = driver.find_element_by_css_selector('.track__name')
    artist = elem.find_element_by_class_name('track__artists').text
    title = elem.find_element_by_class_name('track__title').text
    
    tracks = driver.find_element_by_css_selector('.page-album__tracks').\
        find_elements_by_class_name('d-track')
    
    for track_i, track in enumerate(tracks, 1):
        if 'd-track_playing' in track.get_attribute("class").split(' '):
            break
    
    print("Now playing: {} - {}".format(artist, title))
    print("{}th track of {} tracks".format(track_i, len(tracks)))
    
    sleep(10)
# Out:
# Now playing:  -
# 4th track of 12 tracks

# %% [markdown]
# И многое, многое другое... 😊

# %% [markdown]
# ## Selenium — инструмент тестирования
#
# [Katalon Recorder](https://www.katalon.com/) (Selenium IDE): [Chrome Extension](https://chrome.google.com/webstore/detail/katalon-recorder-selenium/ljdobmomdgdljniojadhoplhkpialdid), [Firefox Extension](https://addons.mozilla.org/en-US/firefox/addon/katalon-automation-record/)
#
# chrome://extensions/
#
# https://mail.ru/ --> "кто такой филантроп?"
